# %% [markdown]
# Boucle globale de lecture de vidéo
#
#
# state= 0
#     img_calibration
#     obstacle detection
#     start and goal
#     global_nav
#
# state = 1
#     img_calibration
#     detect Thymio
#     astolfi ou local nav

# %%
#lancer la communication asynchrone avec thymio
from tdmclient import ClientAsync, aw
client = ClientAsync()
node = await client.wait_for_node()
await node.lock()

#vérifier d'avoir installer pyserial
# Out:
# Node eb16048f-962c-44b2-9651-cc3b67bca83b

# %% [markdown]
# # Initialisation

# %%
#check each import if it's really necessary
import cv2 
import time
import numpy as np
from PIL import Image 
import math
import matplotlib
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt

#import from global control
#import from glocal + control
import pyvisgraph as vg
import geopandas as gpd
from geopandas import GeoSeries
from shapely.geometry import Polygon, Point, LineString
import time

# %%
import Vision as vis
import Global as glob
import control as ctrl
import local_nav as local

# fonction et classe filtering
from kalman_step_astolfi import kalman_step_complet
from EKF_astolfi import ExtendedKalmanFilterAstolfi

# %%
#pour le test utilise une image mais en vrai relier à la caméra et temps réel

cap=cv2.VideoCapture(1,cv2.CAP_DSHOW)

for i in range (5):
    _, frame = cap.read()
    time.sleep(1)
    print("frame {}".format(i))

cap.release()


#img_final= cv2.flip(img_final, 0)
img_final2 = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
corner_coord=vis.find_corners(img_final2)
img=vis.img_calibration(img_final2,corner_coord)
#cv2.imwrite('warpped.png', zzz)
plt.figure()
plt.imshow(img)
plt.show()

# %%
#obstacle detection
polygons=vis.obstacle_detection(img)
#Start and goal detection
start=vis.detectCircle(img,'start')
goal=vis.detectCircle(img,'goal')

# %%
#plot the visibility graph

#a voir si on le met dedans
margin = 35
path=glob.global_pathplanning(start,goal,polygons,margin)

# %% [markdown]
# # Control and navigation loop

# %%
#cap=cv2.VideoCapture(0)

# %%
cap=cv2.VideoCapture(1,cv2.CAP_DSHOW)

for i in range (5):
    _, frame = cap.read()
    time.sleep(1)
    print("frame {}".format(i))

cap.release()
    
#frame=vis.img_calibration(frame)
    
plt.figure()
plt.imshow(frame)
plt.show()

# %%
#img_final = cv2.imread(frame)
img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#img= cv2.flip(img, 0)
final=vis.img_calibration(img)
plt.figure()
plt.imshow(final)
plt.show()

# %%
def initialisation(pic):
    #obstacle detection
    polygons=vis.obstacle_detection(pic)
    #Start and goal detection
    start=vis.detectCircle(pic,'start')
    goal=vis.detectCircle(pic,'goal')
    init=[start,goal,polygons]
    return init

# %%
def printThymio(posThym, coordThym):
    coordThym.append((round(pos_thym[0]),round(pos_thym[1]))) #pos_thym = [x,y]
    for i in range(0,len(coordThym)):
        cv2.circle(final,(int(coordThym[i][0]),int(coordThym[i][1])), int(3), (0,255,255), 2)

# %%
def printThymioKalm(posThym, coordThym):    #la couleur de la trace change
    coordThym.append((round(pos_thym[0]),round(pos_thym[1]))) #pos_thym = [x,y]
    for i in range(0,len(coordThym)):
        cv2.circle(final,(int(coordThym[i][0]),int(coordThym[i][1])), int(3), (0,0,255), 2)

# %%
#convertir frame to real => mm/s vitesse et position

#coefficients for the Astolfi controller (distances in millimeter)
r=22
l=48 
kp=25  #2 #>0
ka=50  #must be > kp
kb=-0.0001 #<0

#coeff_commtoreal=0,38

#astolfi return to iterate on the next goal from the path list

def astolfi(actual_pos, goal_pos, actual_angle, node):
    #déplacer les variables à l'extérieur dans control
    switch_next=0
    thresh_close2=10
    thresh_close1=75
    comm_sat_min=100
    comm_sat_max=250
    
    delta=np.subtract(goal_pos,actual_pos)
    pho=np.sqrt(np.sum(np.square(delta)))
    alpha=-np.radians(actual_angle) + np.arctan2(-delta[1],delta[0])
    beta=-actual_angle-alpha
    v=kp*pho
    if(pho<thresh_close1):
        v=comm_sat_min*r
    if(pho<thresh_close2):
        v=0
        switch_next=1      
    omega=ka*alpha+kb*beta
    #omega=0
    right_speed=(l*omega+v)/r
    left_speed=(v-l*omega)/r
    left_speed=int(left_speed)
    right_speed=int(right_speed)
    ctrl.set_motors(left_speed, right_speed, node)
    return switch_next

# %%
def printGlobalPath(path, img):
    lineThickness = 3
    for i in range(0,len(path)-1):
        cv2.line(final, (round(path[i][0]), round(path[i][1])),(round(path[i+1][0]), round(path[i+1][1])), (0,255,0), lineThickness)

# %%
cap=cv2.VideoCapture(1,cv2.CAP_DSHOW)
for i in range (5):
    _, frame = cap.read()
    time.sleep(1)
    print("frame {}".format(i))

#cap.release()
#plt.figure()
#plt.imshow(frame)
#plt.show()

#time.sleep(1)
state=0
margin = 40
switch_next=0
path_iter=1
obst = [0,0,0,0,0]   # measurements from front prox sensors
obstThrL = 2500      # low obstacle threshold to switch state 3->2
obstThrL2 = 3000
obstThrH = 3500      # high obstacle threshold to switch state 2->3  #max 4000
y = [0,0]          # powers given to motor wheels

#init des variables Kalman, et visu de la trace
KF = ExtendedKalmanFilterAstolfi()
KF.init_state_vector(0,0,0,0,0,0,0,0)   #xxx a rendre plus joli
KF.set_time_stamp(time.time())

sensor_package = []
kalman_pos = []

coordThym = []
coordKalm = []

while (cap.isOpened()):
    _, frame = cap.read()
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    #final=vis.img_calibration(img, corner_coord)
    #img= cv2.flip(img, 0)
    if(state==0):
        corner_coord=vis.find_corners(img)
        final=vis.img_calibration(img, corner_coord)
        init=initialisation(final)
        path=glob.global_pathplanning(init[0],init[1],init[2],margin)
        state=2
    #if state==1:
     #   time.sleep(6)
      #  print("time sleep over")
       # _, frame1 = cap.read()
        #plt.figure()
        #plt.imshow(frame1)
        #plt.show()
        #img1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)
        #state=2
    if (state==2):
        final=vis.img_calibration(img, corner_coord)
        #plt.figure()
        #plt.imshow(final1)
        #plt.show()
        pos_thym=vis.detectThymio(final)[0]
        angle_thym=vis.directionThymio(final)
        
        vit_roue_droite = ctrl.read_motors_speed(node,client)[0]#xxx droite ou gauche a verifier
        vit_roue_gauche = ctrl.read_motors_speed(node,client)[1]#droite ou gauche a verifier
        sensor_package = [pos_thym[0], pos_thym[1], angle_thym, vit_roue_droite, vit_roue_gauche]
        E = kalman_step_complet(sensor_package,KF)
        kalman_pos = [E[0], E[1]]
        print("kalman pos: {}".format(kalman_pos[0]))
        angle_kalman=E[2]
        print("kalman angle: {}".format(angle_kalman))
        #print(pos_thym)
        #print(angle_thym)
        #y = [50,50]
        #ctrl.set_motors(y[0],y[1],node)
        
        switch_next=astolfi(pos_thym,path[path_iter],angle_thym,node)
        if(switch_next==1):
            path_iter=path_iter+1
            print("path iter ",path_iter)
            if(path_iter==len(path)):
                ctrl.stopmotors(node)
                print("finish")
                state=4
                
        #local avoidance
        # get the proximity sensors values and obstacle update
        #prox_horizontal = ctrl.read_prox_sensors(node,client)
        #obst = [prox_horizontal[0], prox_horizontal[1], prox_horizontal[2], prox_horizontal[3], prox_horizontal[4]]
        # update the state between state 2 and state 3
        #state = local.update_state2(state,obstThrL,obstThrH, obst) 
        
    if(state==3):
        print("local_nav")
        # get the proximity sensors values and obstacle update
        prox_horizontal = ctrl.read_prox_sensors(node,client)
        obst = [prox_horizontal[0], prox_horizontal[1], prox_horizontal[2], prox_horizontal[3], prox_horizontal[4]]
        # update the state between state 2 and state 3
        state = local.update_state2(state,obstThrL,obstThrH, obst)  
        #print("obstacles values", obst)
        y_memory = ctrl.read_motors_speed(node,client)
        y = local.local_nav(prox_horizontal,y_memory)
        #print("y ",y)
        ctrl.set_motors(y[0],y[1],node)
        
    if state==4:
        break
    vis.printGlobalPath(path, final)
   # printThymio(pos_thym, coordThym)
    printThymioKalm(kalman_pos,coordKalm)
    cv2.imshow("results", final)
    if cv2.waitKey(1) & 0xFF ==ord('q'):
        break
        
cap.release()
#cv2.destroyAllWindows()
# Out:
# frame 0
# frame 1
# frame 2
# frame 3
# frame 4
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 199.84it/s]
# Visibility graph points:  [[Point(465.42, 205.76), Point(391.70, 327.86), Point(516.59, 392.62), Point(590.30, 272.83)], [Point(264.84, 198.99), Point(107.25, 203.03), Point(110.77, 388.01), Point(270.13, 383.97)], [Point(358.20, -27.00), Point(260.82, 75.01), Point(368.18, 166.38), Point(467.88, 66.69)], [Point(-7.52, -25.00), Point(-5.47, 132.73), Point(182.48, 129.28), Point(184.54, -25.00)]]
#
# Shortest path distance: 639.4444256105298
#
# 0    POLYGON ((465.417 205.765, 391.697 327.863, 51...
# 1    POLYGON ((264.845 198.991, 107.250 203.032, 11...
# 2    POLYGON ((358.200 -26.998, 260.825 75.014, 368...
# 3    POLYGON ((-7.523 -25.000, -5.474 132.731, 182....
# 0                               POINT (42.744 341.529)
# 1                              POINT (107.250 203.032)
# 2                              POINT (368.184 166.384)
# 3                               POINT (557.329 47.946)
# dtype: geometry
#
# path  0     POINT (42.744 341.529)
# 1    POINT (107.250 203.032)
# 2    POINT (368.184 166.384)
# 3     POINT (557.329 47.946)
# dtype: geometry
# 2
# 2
# temps entre samples:  0.2522261142730713
# kalman pos: 24.834200329974774
# kalman angle: 60.45034879761746
# 2
# 2
# temps entre samples:  0.15010690689086914
# kalman pos: 32.83416254144645
# kalman angle: 63.00920884330959
# 2
# 2
# temps entre samples:  0.14572954177856445
# kalman pos: 36.98576829277381
# kalman angle: 63.674274830565274
# 2
# 2
# temps entre samples:  0.15721940994262695
# kalman pos: 39.86836267494362
# kalman angle: 64.4637708061505
# 2
# 2
# temps entre samples:  0.13593196868896484
# kalman pos: 17.337451012786648
# kalman angle: 64.36477475298932
# 2
# 2
# temps entre samples:  0.14498043060302734
# kalman pos: -53.994716376749125
# kalman angle: 60.9766778859629
# 2
# 2
# temps entre samples:  0.1351461410522461
# kalman pos: -123.5006879834165
# kalman angle: 52.021174368452876
# 2
# 2
# temps entre samples:  0.14735817909240723
# kalman pos: 47.259923993645366
# kalman angle: 52.83080388859748
# 2
# 2
# temps entre samples:  0.13432931900024414
# kalman pos: -109.41559367508825
# kalman angle: 47.02650589084613
# 2
# 2
# temps entre samples:  0.14644813537597656
# kalman pos: -128.9922294826082
# kalman angle: 34.033453937971764
# 2
# 2
# temps entre samples:  0.13534879684448242
# kalman pos: -71.03909682102646
# kalman angle: 23.101050617675646
# 2
# 2
# temps entre samples:  0.14609026908874512
# kalman pos: -57.84896769230974
# kalman angle: 14.763092998914315
# 2
# 2
# temps entre samples:  0.1359856128692627
# kalman pos: 16.914363288766758
# kalman angle: 12.044424369906674
# 2
# 2
# temps entre samples:  0.14767956733703613
# kalman pos: -10.981502330511205
# kalman angle: 9.663466851610625
# 2
# 2
# temps entre samples:  0.13519549369812012
# kalman pos: 21.53691070110029
# kalman angle: 10.011952202240066
# 2
# 2
# temps entre samples:  0.14632129669189453
# kalman pos: 33.7836644700689
# kalman angle: 9.673250230039683
# 2
# 2
# temps entre samples:  0.13400816917419434
# kalman pos: 54.40722202058395
# kalman angle: 8.9060675629603
# 2
# 2
# temps entre samples:  0.14564132690429688
# kalman pos: 58.216494141167715
# kalman angle: 7.753860228664024
# 2
# 2
# temps entre samples:  0.13680815696716309
# kalman pos: 41.23697654889843
# kalman angle: 6.756494304622645
# 2
# 2
# temps entre samples:  0.1361987590789795
# kalman pos: 21.762088449616897
# kalman angle: 6.4322939414341835
# 2
# 2
# temps entre samples:  0.14624762535095215
# kalman pos: 18.42988707167416
# kalman angle: 6.841707809854579
# 2
# 2
# temps entre samples:  0.13556599617004395
# kalman pos: 22.46979075647268
# kalman angle: 7.499993119572936
# 2
# 2
# temps entre samples:  0.14178800582885742
# kalman pos: 16.136050616134202
# kalman angle: 7.824934540395537
# 2
# 2
# temps entre samples:  0.14551281929016113
# kalman pos: 0.41666404914297495
# kalman angle: 7.494162982529624
# 2
# 2
# temps entre samples:  0.1354813575744629
# kalman pos: -8.497325299879616
# kalman angle: 6.810040294616852
# 2
# 2
# temps entre samples:  0.1466667652130127
# kalman pos: -8.003787134650928
# kalman angle: 5.892419036715561
# 2
# 2
# temps entre samples:  0.13510370254516602
# kalman pos: 6.63416791607731
# kalman angle: 5.1597114734183505
# 2
# 2
# temps entre samples:  0.1492774486541748
# kalman pos: 32.267472078976496
# kalman angle: 4.923293636587028
# 2
# 2
# temps entre samples:  0.13622760772705078
# kalman pos: 57.77072973265681
# kalman angle: 5.162653386651319
# 2
# 2
# temps entre samples:  0.13472914695739746
# kalman pos: 81.71616768613674
# kalman angle: 5.5652927532908
# 2
# 2
# temps entre samples:  0.14779138565063477
# kalman pos: 104.89972568041117
# kalman angle: 5.774233051393112
# 2
# 2
# temps entre samples:  0.13355684280395508
# kalman pos: 116.94432292646897
# kalman angle: 5.582688377347014
# 2
# 2
# temps entre samples:  0.14931964874267578
# kalman pos: 123.16549702018332
# kalman angle: 5.115614154713004
# 2
# 2
# temps entre samples:  0.13600444793701172
# kalman pos: 128.19858825204497
# kalman angle: 4.636812427187025
# 2
# 2
# temps entre samples:  0.13648104667663574
# kalman pos: 135.1212047916532
# kalman angle: 4.272523899563005
# 2
# 2
# temps entre samples:  0.14697265625
# kalman pos: 142.35366132977808
# kalman angle: 4.144511692441593
# 2
# 2
# temps entre samples:  0.13571929931640625
# kalman pos: 145.58821147249682
# kalman angle: 4.159899624722799
# 2
# 2
# temps entre samples:  0.1450798511505127
# kalman pos: 148.3425541102592
# kalman angle: 4.192810266640964
# 2
# 2
# temps entre samples:  0.13621258735656738
# kalman pos: 149.96383790592364
# kalman angle: 4.194256904309389
# 2
# 2
# temps entre samples:  0.14450454711914062
# kalman pos: 151.57927762239945
# kalman angle: 4.130473739622614
# 2
# 2
# temps entre samples:  0.14426803588867188
# kalman pos: 151.74135540233786
# kalman angle: 4.010312857928565
# 2
# 2
# temps entre samples:  0.13638710975646973
# kalman pos: 150.14363633684144
# kalman angle: 3.8953220767140184
# 2
# 2
# temps entre samples:  0.13590788841247559
# kalman pos: 147.7183800560983
# kalman angle: 3.8164993491909898
# path iter  2
# 2
# 2
# temps entre samples:  0.14691686630249023
# kalman pos: 144.5684235923903
# kalman angle: 3.739013214706396
# 2
# 2
# temps entre samples:  0.13565802574157715
# kalman pos: 140.5337843244822
# kalman angle: 3.687161325108993
# 2
# 2
# temps entre samples:  0.14649653434753418
# kalman pos: 136.0602625143347
# kalman angle: 3.6064539549038255
# 2
# 2
# temps entre samples:  0.13453388214111328
# kalman pos: 131.6714177706554
# kalman angle: 3.609467148087422
# 2
# 2
# temps entre samples:  0.1378772258758545
# kalman pos: 127.26573636166859
# kalman angle: 3.574420539837253
# 2
# 2
# temps entre samples:  0.14773893356323242
# kalman pos: 124.28255731788958
# kalman angle: 3.4829732799667106
# 2
# 2
# temps entre samples:  0.13613104820251465
# kalman pos: 121.42046399092501
# kalman angle: 3.3736124291128378
# 2
# 2
# temps entre samples:  0.14771676063537598
# kalman pos: 117.98489140016595
# kalman angle: 3.189555700311825
# 2
# 2
# temps entre samples:  0.13577795028686523
# kalman pos: 113.66685129461278
# kalman angle: 2.9800719698860765
# 2
# 2
# temps entre samples:  0.14720964431762695
# kalman pos: 108.03786610439626
# kalman angle: 2.7347004338500702
# 2
# 2
# temps entre samples:  0.1337299346923828
# kalman pos: 102.65718107468219
# kalman angle: 2.444588900551683
# 2
# 2
# temps entre samples:  0.13654589653015137
# kalman pos: 97.47155399634622
# kalman angle: 2.1112813533574872
# 2
# 2
# temps entre samples:  0.14740443229675293
# kalman pos: 94.2897698131616
# kalman angle: 1.6972977026077636
# 2
# 2
# temps entre samples:  0.13519906997680664
# kalman pos: 96.21762822805243
# kalman angle: 1.2685941506651148
# 2
# 2
# temps entre samples:  0.14679265022277832
# kalman pos: 103.73093734305435
# kalman angle: 0.7836401821948453
# 2
# 2
# temps entre samples:  0.13333964347839355
# kalman pos: 117.03440735654351
# kalman angle: 0.3555800260658108
# 2
# 2
# temps entre samples:  0.14478707313537598
# kalman pos: 134.33174878605686
# kalman angle: -0.012661171956519057
# 2
# 2
# temps entre samples:  0.13692378997802734
# kalman pos: 150.83996279176182
# kalman angle: -0.2883264311279476
# 2
# 2
# temps entre samples:  0.1475985050201416
# kalman pos: 164.28280543571464
# kalman angle: -0.3955019340648285
# 2
# 2
# temps entre samples:  0.13698291778564453
# kalman pos: 173.98331026538466
# kalman angle: -0.35692928144997915
# 2
# 2
# temps entre samples:  0.1471877098083496
# kalman pos: 183.0451474986483
# kalman angle: -0.19139201685112756
# 2
# 2
# temps entre samples:  0.13352632522583008
# kalman pos: 191.96634173573395
# kalman angle: -0.022942194801781224
# 2
# 2
# temps entre samples:  0.14467287063598633
# kalman pos: 201.63011013181043
# kalman angle: 0.12540341651240183
# 2
# 2
# temps entre samples:  0.13482069969177246
# kalman pos: 210.26140960670548
# kalman angle: 0.22396281312395455
# 2
# 2
# temps entre samples:  0.14575409889221191
# kalman pos: 218.64978499285522
# kalman angle: 0.2705979590749272
# 3
# 3
# temps entre samples:  0.13567090034484863
# kalman pos: 225.84090682944188
# kalman angle: 0.257612883231473
# 2
# 2
# temps entre samples:  0.14522862434387207
# kalman pos: 233.0038728464794
# kalman angle: 0.25172689139317095
# 2
# 2
# temps entre samples:  0.13573360443115234
# kalman pos: 239.4912358055864
# kalman angle: 0.20814279572622169
# 2
# 2
# temps entre samples:  0.14744997024536133
# kalman pos: 247.78311903981805
# kalman angle: 0.23397789704589794
# 3
# 3
# temps entre samples:  0.13456082344055176
# kalman pos: 255.4164024435096
# kalman angle: 0.254297621181384
# 2
# 2
# temps entre samples:  0.14666438102722168
# kalman pos: 261.1783499150334
# kalman angle: 0.1063425296825958
# 3
# 3
# temps entre samples:  0.13575220108032227
# kalman pos: 265.65395642207835
# kalman angle: 0.06015712518839335
# 2
# 2
# temps entre samples:  0.13783955574035645
# kalman pos: 270.31366555724736
# kalman angle: 0.006511211784580279
# 2
# 2
# temps entre samples:  0.14838385581970215
# kalman pos: 275.3052994957921
# kalman angle: -0.06700416352504529
# 2
# 2
# temps entre samples:  0.13387060165405273
# kalman pos: 279.11799326162907
# kalman angle: -0.08266699777074993
# 2
# 2
# temps entre samples:  0.14669322967529297
# kalman pos: 283.24596096508867
# kalman angle: -0.12476753969032145
# 2
# 2
# temps entre samples:  0.13404488563537598
# kalman pos: 286.30899555441636
# kalman angle: -0.13461813317361856
# 2
# 2
# temps entre samples:  0.14535069465637207
# kalman pos: 289.86489794158473
# kalman angle: -0.15114414228525197
# 2
# 2
# temps entre samples:  0.14554429054260254
# kalman pos: 293.32681690327547
# kalman angle: -0.1495305081210673
# 2
# 2
# temps entre samples:  0.13431024551391602
# kalman pos: 296.01243564128083
# kalman angle: -0.16398350722298496
# 2
# 2
# temps entre samples:  0.13792204856872559
# kalman pos: 298.9299630190852
# kalman angle: -0.14564495815587616
# 2
# 2
# temps entre samples:  0.1475210189819336
# kalman pos: 301.84473009946885
# kalman angle: -0.12888315211326914
# 2
# 2
# temps entre samples:  0.13441753387451172
# kalman pos: 304.2702878052347
# kalman angle: -0.11828442753878676
# 2
# 2
# temps entre samples:  0.14636778831481934
# kalman pos: 307.0834578961394
# kalman angle: -0.1149264518256907
# 2
# 2
# temps entre samples:  0.13561296463012695
# kalman pos: 309.31201088035573
# kalman angle: -0.09752063421641245
# 2
# 2
# temps entre samples:  0.13852787017822266
# kalman pos: 311.4648422273604
# kalman angle: -0.11196728708862148
# 2
# 2
# temps entre samples:  0.14809393882751465
# kalman pos: 313.97281525084213
# kalman angle: -0.10869104324941095
# 2
# 2
# temps entre samples:  0.13264846801757812
# kalman pos: 315.88162309375105
# kalman angle: -0.08632183088041272
# 2
# 2
# temps entre samples:  0.14806771278381348
# kalman pos: 318.0951155607958
# kalman angle: -0.07767679013255
# 2
# 2
# temps entre samples:  0.13593029975891113
# kalman pos: 320.01273995544364
# kalman angle: -0.08390093336430038
# 2
# 2
# temps entre samples:  0.14722251892089844
# kalman pos: 322.1213430330946
# kalman angle: -0.11634698836497862
# 2
# 2
# temps entre samples:  0.13522815704345703
# kalman pos: 323.9663602617689
# kalman angle: -0.12445617060075306
# 2
# 2
# temps entre samples:  0.13702964782714844
# kalman pos: 325.8470808854617
# kalman angle: -0.11052647218851336
# 2
# 2
# temps entre samples:  0.14805841445922852
# kalman pos: 328.02484045542076
# kalman angle: -0.1336224320084961
# 2
# 2
# temps entre samples:  0.13604116439819336
# kalman pos: 329.83018190768524
# kalman angle: -0.159464659010558
# 2
# 2
# temps entre samples:  0.14621567726135254
# kalman pos: 331.9424242969555
# kalman angle: -0.16204753522372628
# 2
# 2
# temps entre samples:  0.1340956687927246
# kalman pos: 333.92281134197555
# kalman angle: -0.19880028702149516
# 2
# 2
# temps entre samples:  0.14742326736450195
# kalman pos: 336.18719050188844
# kalman angle: -0.23488734157566135
# 2
# 2
# temps entre samples:  0.1349046230316162
# kalman pos: 337.9996939968479
# kalman angle: -0.2059914063483375
# 2
# 2
# temps entre samples:  0.1466381549835205
# kalman pos: 340.28755826701746
# kalman angle: -0.19166422559790633
# 2
# 2
# temps entre samples:  0.13570237159729004
# kalman pos: 342.2128067689543
# kalman angle: -0.21175096011232325
# 2
# 2
# temps entre samples:  0.13515257835388184
# kalman pos: 344.24395046328414
# kalman angle: -0.21393702057673833
# 2
# 2
# temps entre samples:  0.14710783958435059
# kalman pos: 346.5428355393297
# kalman angle: -0.2112270873867961
# 2
# 2
# temps entre samples:  0.13554859161376953
# kalman pos: 348.7595294106728
# kalman angle: -0.20926452033963505
# 2
# 2
# temps entre samples:  0.14561176300048828
# kalman pos: 351.05676738953065
# kalman angle: -0.20687470065098984
# 2
# 2
# temps entre samples:  0.1352372169494629
# kalman pos: 353.2192654199672
# kalman angle: -0.20204640538978677
# 2
# 2
# temps entre samples:  0.14505600929260254
# kalman pos: 355.49721819583874
# kalman angle: -0.2604938270337415
# 2
# 2
# temps entre samples:  0.13736915588378906
# kalman pos: 357.71783177186853
# kalman angle: -0.2848640134528555
# 2
# 2
# temps entre samples:  0.14586257934570312
# kalman pos: 359.8782779501064
# kalman angle: -0.314737483843549
# 2
# 2
# temps entre samples:  0.13352632522583008
# kalman pos: 361.8716050789104
# kalman angle: -0.2923440887427077
# 2
# 2
# temps entre samples:  0.1464850902557373
# kalman pos: 364.3380723842807
# kalman angle: -0.269195844897612
# 2
# 2
# temps entre samples:  0.1376175880432129
# kalman pos: 366.50311394075936
# kalman angle: -0.2373991814248977
# 2
# 2
# temps entre samples:  0.14626669883728027
# kalman pos: 368.8096014712453
# kalman angle: -0.23659162152730948
# path iter  3
# 2
# 2
# temps entre samples:  0.13410711288452148
# kalman pos: 371.0012024431663
# kalman angle: -0.20857847112871392
# 2
# 2
# temps entre samples:  0.14619731903076172
# kalman pos: 373.1024302215152
# kalman angle: -0.19607475624206566
# 2
# 2
# temps entre samples:  0.13433837890625
# kalman pos: 376.1017620770907
# kalman angle: -0.1965739382506389
# 2
# 2
# temps entre samples:  0.1463634967803955
# kalman pos: 380.4758270240504
# kalman angle: -0.16433242582835744
# 2
# 2
# temps entre samples:  0.13407564163208008
# kalman pos: 385.26851794899073
# kalman angle: -0.1007117867469464
# 2
# 2
# temps entre samples:  0.14688611030578613
# kalman pos: 390.6976237270318
# kalman angle: -0.012131723434730998
# 2
# 2
# temps entre samples:  0.13449621200561523
# kalman pos: 396.49611674965894
# kalman angle: 0.14882567166314958
# 2
# 2
# temps entre samples:  0.14689016342163086
# kalman pos: 402.60571611772514
# kalman angle: 0.2811044027738586
# 2
# 2
# temps entre samples:  0.13579058647155762
# kalman pos: 407.8175876675951
# kalman angle: 0.3830979578325806
# 2
# 2
# temps entre samples:  0.14915966987609863
# kalman pos: 413.3888190032588
# kalman angle: 0.4638043640709071
# 2
# 2
# temps entre samples:  0.13522768020629883
# kalman pos: 418.0662888436684
# kalman angle: 0.5306315707959908
# 2
# 2
# temps entre samples:  0.13539838790893555
# kalman pos: 422.4916229034873
# kalman angle: 0.5456466346478427
# 2
# 2
# temps entre samples:  0.14818453788757324
# kalman pos: 427.3849078443245
# kalman angle: 0.5287515871698864
# 2
# 2
# temps entre samples:  0.13524270057678223
# kalman pos: 431.8265070657393
# kalman angle: 0.5357247377895845
# 2
# 2
# temps entre samples:  0.14565229415893555
# kalman pos: 437.02283361792627
# kalman angle: 0.5332275301624566
# 2
# 2
# temps entre samples:  0.13585948944091797
# kalman pos: 442.4799288883014
# kalman angle: 0.496586839709769
# 2
# 2
# temps entre samples:  0.14886474609375
# kalman pos: 448.1706035283734
# kalman angle: 0.47441546776432636
# 2
# 2
# temps entre samples:  0.13486647605895996
# kalman pos: 453.3949233583777
# kalman angle: 0.48796217863971153
# 2
# 2
# temps entre samples:  0.14617419242858887
# kalman pos: 459.04469211426857
# kalman angle: 0.5110044378039669
# 2
# 2
# temps entre samples:  0.14824295043945312
# kalman pos: 464.0778499300764
# kalman angle: 0.5408692917022941
# 2
# 2
# temps entre samples:  0.1484689712524414
# kalman pos: 469.0765801141519
# kalman angle: 0.5660327355575199
# 2
# 2
# temps entre samples:  0.13513588905334473
# kalman pos: 473.3711936234726
# kalman angle: 0.5904275196350901
# 2
# 2
# temps entre samples:  0.1360640525817871
# kalman pos: 477.0879388562023
# kalman angle: 0.6413669938200226
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.1453256607055664
# kalman pos: 480.4488410756227
# kalman angle: 0.7034405201478764
# 2
# 2
# temps entre samples:  0.13823342323303223
# kalman pos: 482.92737406767395
# kalman angle: 0.8025516984951974
# 2
# 2
# temps entre samples:  0.14698028564453125
# kalman pos: 484.926187456236
# kalman angle: 0.8899196751422453
# 2
# 2
# temps entre samples:  0.13581466674804688
# kalman pos: 486.13757379674496
# kalman angle: 0.973836611360832
# 3
# 3
# temps entre samples:  0.1442573070526123
# kalman pos: 486.54736929043963
# kalman angle: 1.0538732347377076
# 2
# 2
# temps entre samples:  0.13526415824890137
# kalman pos: 486.2546729326491
# kalman angle: 1.1950192463682936
# 5
# 5
# temps entre samples:  0.14635539054870605
# kalman pos: 485.38404080220806
# kalman angle: 1.3087065941165115
# failure in identifying corners
# 3
# 3
# temps entre samples:  0.13873672485351562
# kalman pos: 483.8016148514217
# kalman angle: 1.42609475441548
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.1353306770324707
# kalman pos: 481.38556604709635
# kalman angle: 1.5657801269173273
# 4
# 4
# temps entre samples:  0.14487171173095703
# kalman pos: 478.07955881107375
# kalman angle: 1.6982278331156992
# failure in identifying corners
# 3
# 3
# temps entre samples:  0.13747620582580566
# kalman pos: 475.2329339052782
# kalman angle: 1.8193182301539967
# 3
# 3
# temps entre samples:  0.1470038890838623
# kalman pos: 471.5687453051973
# kalman angle: 1.9525542608661788
# 2
# 2
# temps entre samples:  0.13615989685058594
# kalman pos: 468.66788606087624
# kalman angle: 2.105547090856159
# 2
# 2
# temps entre samples:  0.13628888130187988
# kalman pos: 466.0266071791833
# kalman angle: 2.246088905632184
# 4
# 4
# temps entre samples:  0.14592719078063965
# kalman pos: 463.0739238799401
# kalman angle: 2.3893756173314324
# failure in identifying corners
# 3
# 3
# temps entre samples:  0.13583159446716309
# kalman pos: 461.3860751378331
# kalman angle: 2.5369621665370334
# 3
# 3
# temps entre samples:  0.14710092544555664
# kalman pos: 459.455136901074
# kalman angle: 2.7182361513634907
# 2
# 2
# temps entre samples:  0.13663768768310547
# kalman pos: 459.62704268756136
# kalman angle: 2.908295542251225
# 2
# 2
# temps entre samples:  0.1476140022277832
# kalman pos: 460.19297834773295
# kalman angle: 3.115461340562359
# 2
# 2
# temps entre samples:  0.13637971878051758
# kalman pos: 462.5052151242439
# kalman angle: 3.3633059520688438
# 2
# 2
# temps entre samples:  0.13602399826049805
# kalman pos: 466.6938415266695
# kalman angle: 3.608989918043218
# 2
# 2
# temps entre samples:  0.14715123176574707
# kalman pos: 473.043022174307
# kalman angle: 3.8594074896078547
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.13724064826965332
# kalman pos: 481.7690219853816
# kalman angle: 4.169397638763088
# 2
# 2
# temps entre samples:  0.13719987869262695
# kalman pos: 493.0025732560792
# kalman angle: 4.461434260176837
# 2
# 2
# temps entre samples:  0.14824485778808594
# kalman pos: 507.39113776485317
# kalman angle: 4.781743129854875
# 2
# 2
# temps entre samples:  0.13463687896728516
# kalman pos: 522.2918299435248
# kalman angle: 5.09768220327176
# 2
# 2
# temps entre samples:  0.148193359375
# kalman pos: 539.2816923276005
# kalman angle: 5.409244294110276
# 2
# 2
# temps entre samples:  0.13414907455444336
# kalman pos: 553.5796486065631
# kalman angle: 5.703098788533776
# 2
# 2
# temps entre samples:  0.1458122730255127
# kalman pos: 566.5448979646283
# kalman angle: 5.948676358470914
# 2
# 2
# temps entre samples:  0.13407111167907715
# kalman pos: 573.9916001599594
# kalman angle: 6.127576030484362
# 2
# 2
# temps entre samples:  0.14867210388183594
# kalman pos: 577.3407320526316
# kalman angle: 6.170925115346908
# 2
# 2
# temps entre samples:  0.13631224632263184
# kalman pos: 576.0154355279939
# kalman angle: 6.090093430426268
# 2
# 2
# temps entre samples:  0.13960576057434082
# kalman pos: 573.7583586566684
# kalman angle: 5.8215915263819
# 2
# 2
# temps entre samples:  0.13618206977844238
# kalman pos: 573.1513691789869
# kalman angle: 5.459009807776353
# 2
# 2
# temps entre samples:  0.15616178512573242
# kalman pos: 577.3164697951048
# kalman angle: 4.947898084902935
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.1465897560119629
# kalman pos: 583.2221189694579
# kalman angle: 4.501352830627774
# 2
# 2
# temps entre samples:  0.13683271408081055
# kalman pos: 588.9510379661223
# kalman angle: 4.2190801328281875
# 2
# 2
# temps entre samples:  0.14674901962280273
# kalman pos: 594.2295993114162
# kalman angle: 4.131107941557172
# 2
# 2
# temps entre samples:  0.13645577430725098
# kalman pos: 596.0493532294062
# kalman angle: 4.108171102911728
# 2
# 2
# temps entre samples:  0.13790154457092285
# kalman pos: 597.6633962817599
# kalman angle: 4.1581027240473105
# 2
# 2
# temps entre samples:  0.14980030059814453
# kalman pos: 599.2650519290136
# kalman angle: 4.154783676627371
# 2
# 2
# temps entre samples:  0.13453078269958496
# kalman pos: 599.7036150063312
# kalman angle: 4.110342774530121
# 2
# 2
# temps entre samples:  0.13623738288879395
# kalman pos: 599.2402702581024
# kalman angle: 3.988274937192436
# 2
# 2
# temps entre samples:  0.14760541915893555
# kalman pos: 598.7959080336699
# kalman angle: 3.8899513324694768
# path iter  4
# finish

# %%
print("kalman pos: ",kalman_pos)
print("kalman pos: ", np.asarray(kalman_pos[0][0]))
print("kalman pos: ", np.squeeze(np.asarray(kalman_pos))[0])
# Out:
# kalman pos:  [matrix([[34.35062237]]), matrix([[170.58868398]])]
# kalman pos:  [[34.35062237]]
# kalman pos:  34.3506223710019

# %%
ctrl.stopmotors(node)

# %%
test=[[None,None],[None,None]]
if bool(not test[0][0]):
    print("zeub")
# Out:
# zeub

# %%
def detectThymio(imgRGB):
    pts=[]
    #p1 is the big circle and p2 the little
    p1=[]
    p2=[]
    lower=np.array([10,30,30])
    upper=np.array([40,255,255])
    nb_iterations=1
    img_hsv = cv2.cvtColor(imgRGB, cv2.COLOR_RGB2HSV)
    mask = cv2.inRange(img_hsv, lower, upper)
    img_hsv = cv2.blur(img_hsv,(7,7))
    mask = cv2.erode(mask, None, iterations = nb_iterations)
    mask = cv2.dilate(mask, None, iterations = nb_iterations)
    elements,_ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    print(len(elements))
    if len(elements) > 0:
        #sorting the detected contours by descending area size
        elements.sort(key=cv2.contourArea, reverse=True)
        #finding big circle
        c=elements[0]
        ((x,y),rayon) = cv2.minEnclosingCircle(c)
        #finding little circle
        c2=elements[1]
        ((x2,y2),rayon2) = cv2.minEnclosingCircle(c2)
        p1=[x,y]
        p2=[x2,y2]
        pts=[p1,p2]
    return pts

#print(detectThymio(final))
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
corner_coord=vis.find_corners(frame)
final=vis.img_calibration(frame, corner_coord)
print(detectThymio(final)[0])

# %%
print(init)

# %%
# Navigation initialisation
checkp=1           # goal checkpoint
actual_angle=0     # angle to xy axis
y = [0,0]          # powers given to motor wheels

# FSM initialisation
state = 2          # States FSM 0=global nav, 1=local nav
obst = [0,0,0,0,0]   # measurements from front prox sensors
obstThrL = 2500      # low obstacle threshold to switch state 3->2
obstThrL2 = 3000
obstThrH = 3500      # high obstacle threshold to switch state 2->3 

def update_state(state,obstThrL,obstThrH, obst):
    if state == 2: 
        # switch from goal tracking to obst avoidance if obstacle detected
        if (obst[2] > obstThrH):
            state = 3
            print("change state to local")
        elif (obst[1] > obstThrH):
            state = 3
            print("change state to local")
        elif (obst[3] > obstThrH):
            state = 3
            print("change state to local")
        elif (obst[0] > obstThrH):
            state = 3
            print("change state to local")
        elif (obst[4] > obstThrH):
            state = 3
            print("change state to local")
    elif state == 3:
        if obst[2] < obstThrL:
            if obst[1] < obstThrL:
                if obst[3] < obstThrL:
                    if obst[0] < obstThrL:
                        if obst[4] < obstThrL:
                            # switch from obst avoidance to goal tracking if obstacle got unseen
                            state = 2
                            print("change state to global")
    return state

while True:
    
    # get the proximity sensors values and obstacle update
    prox_horizontal = ctrl.read_prox_sensors(node,client)
    obst = [prox_horizontal[0], prox_horizontal[1], prox_horizontal[2], prox_horizontal[3], prox_horizontal[4]]
    
    # update the state and speed motors values
    state = update_state(state,obstThrL,obstThrH, obst)
    y = ctrl.read_motors_speed(node,client)
    
    print("state", state)

    if state == 2:
        
        """
        # With positon estimation when vision and/or kalman ready
        
        actual,angle = getting_vis()
        pred_pos,pred_angle = kalman(actual, angle)
        
        actual_pos=pred_pos
        actual_angle=pred_angle
        
        if actual_pos == checkpoints[checkp]: # other option: if (actual_pos - checkpoints[checkp]) < error
            checkp=checkp+1
        goal_pos=checkpoints[checkp]
        
        y = ctrl.astolfi2(actual_pos, goal_pos, actual_angle, node)
        
        """
        y = [100,100]
        ctrl.set_motors(y[0],y[1],node)

    elif state == 3:
        print("obstacles values", obst)
        y = local.local_nav(prox_horizontal,y)
        print("y ",y)
        ctrl.set_motors(y[0],y[1],node)

ctrl.stopmotors(node)
# Out:
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [2005, 3523, 0, 0, 0]
# y  [200, -128]
# state 3
# obstacles values [2142, 3621, 0, 0, 0]
# y  [208, -152]
# state 3
# obstacles values [2679, 3515, 0, 0, 0]
# y  [272, -240]
# state 3
# obstacles values [3331, 0, 0, 0, 0]
# y  [264, -248]
# state 3
# obstacles values [2542, 0, 0, 0, 0]
# y  [232, -216]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [3717, 2501, 0, 0, 0]
# y  [72, -88]
# state 3
# obstacles values [0, 2193, 3408, 0, 0]
# y  [-16, -144]
# state 3
# obstacles values [0, 2102, 3699, 0, 0]
# y  [-40, -168]
# state 3
# obstacles values [0, 2500, 3503, 0, 0]
# y  [-20, -196]
# state 3
# obstacles values [0, 2828, 3238, 0, 0]
# y  [-8, -200]
# state 3
# obstacles values [0, 3217, 2320, 0, 0]
# y  [32, -208]
# state 3
# obstacles values [0, 3256, 0, 0, 0]
# y  [80, -168]
# state 3
# obstacles values [1695, 3185, 0, 0, 0]
# y  [140, -220]
# state 3
# obstacles values [2133, 2977, 0, 0, 0]
# y  [228, -284]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [0, 0, 0, 3854, 3071]
# y  [-220, 292]
# state 3
# obstacles values [0, 0, 0, 4514, 4207]
# y  [-356, 404]
# state 3
# obstacles values [0, 0, 0, 3594, 4634]
# y  [-392, 392]
# state 3
# obstacles values [0, 0, 0, 0, 4587]
# y  [-336, 352]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [0, 0, 0, 3626, 3807]
# y  [-200, 272]
# state 3
# obstacles values [0, 0, 0, 3674, 4028]
# y  [-328, 368]
# state 3
# obstacles values [0, 0, 0, 2352, 4462]
# y  [-352, 352]
# state 3
# obstacles values [0, 0, 0, 0, 3943]
# y  [-288, 288]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [0, 0, 3799, 2175, 0]
# y  [-88, -8]
# state 3
# obstacles values [0, 0, 3892, 1980, 0]
# y  [-144, -40]
# state 3
# obstacles values [0, 0, 4009, 2012, 0]
# y  [-172, -60]
# state 3
# obstacles values [0, 0, 3765, 2213, 0]
# y  [-168, -48]
# state 3
# obstacles values [0, 0, 3444, 2473, 0]
# y  [-184, -16]
# state 3
# obstacles values [0, 0, 2773, 2672, 0]
# y  [-192, -8]
# state 3
# obstacles values [0, 0, 2299, 2806, 0]
# y  [-188, 12]
# state 3
# obstacles values [0, 0, 0, 2871, 0]
# y  [-140, 52]
# state 3
# obstacles values [0, 0, 0, 2747, 2057]
# y  [-196, 148]
# state 3
# obstacles values [0, 0, 0, 2543, 2351]
# y  [-212, 188]
# state 3
# obstacles values [0, 0, 0, 2035, 2719]
# y  [-232, 216]
# state 3
# obstacles values [0, 0, 0, 0, 2836]
# y  [-216, 208]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [0, 0, 0, 4405, 3163]
# y  [-188, 260]
# state 3
# obstacles values [0, 0, 0, 4465, 3409]
# y  [-284, 324]
# state 3
# obstacles values [0, 0, 0, 4432, 4373]
# y  [-364, 404]
# state 3
# obstacles values [0, 0, 0, 2971, 4633]
# y  [-328, 344]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [0, 0, 4089, 2389, 0]
# y  [-100, -20]
# state 3
# obstacles values [0, 0, 4617, 2722, 0]
# y  [-128, -8]
# state 3
# obstacles values [0, 0, 4643, 2812, 0]
# y  [-200, -40]
# state 3
# obstacles values [0, 0, 4186, 3253, 0]
# y  [-260, -28]
# state 3
# obstacles values [0, 0, 3658, 3471, 0]
# y  [-264, -8]
# state 3
# obstacles values [0, 0, 3073, 3701, 0]
# y  [-260, 12]
# state 3
# obstacles values [0, 0, 2128, 3567, 0]
# y  [-264, 160]
# state 3
# obstacles values [0, 0, 0, 3208, 2714]
# y  [-320, 248]
# state 3
# obstacles values [0, 0, 0, 2384, 3335]
# y  [-312, 272]
# state 3
# obstacles values [0, 0, 0, 0, 3276]
# y  [-280, 240]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [2760, 3608, 0, 0, 0]
# y  [232, -160]
# state 3
# obstacles values [2764, 3424, 0, 0, 0]
# y  [248, -184]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [3614, 2851, 0, 0, 0]
# y  [260, -188]
# state 3
# obstacles values [3763, 2834, 0, 0, 0]
# y  [296, -240]
# state 3
# obstacles values [3026, 0, 0, 0, 0]
# y  [224, -248]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [0, 0, 3586, 0, 0]
# y  [-40, -40]
# state 3
# obstacles values [0, 0, 4533, 2602, 0]
# y  [-120, -8]
# state 3
# obstacles values [0, 0, 4787, 2767, 0]
# y  [-200, -40]
# state 3
# obstacles values [0, 0, 4341, 3232, 0]
# y  [-252, -28]
# state 3
# obstacles values [0, 0, 3792, 3400, 0]
# y  [-248, -16]
# state 3
# obstacles values [0, 0, 3031, 3572, 0]
# y  [-228, 4]
# state 3
# obstacles values [0, 0, 0, 3461, 2135]
# y  [-256, 152]
# state 3
# obstacles values [0, 0, 0, 3162, 2647]
# y  [-276, 196]
# state 3
# obstacles values [0, 0, 0, 2337, 3235]
# y  [-304, 248]
# state 3
# obstacles values [0, 0, 0, 0, 3337]
# y  [-232, 208]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [2644, 5062, 3800, 0, 0]
# y  [200, -280]
# state 3
# obstacles values [4211, 5084, 3802, 0, 0]
# y  [320, -464]
# state 3
# obstacles values [4510, 5073, 0, 0, 0]
# y  [432, -448]
# state 3
# obstacles values [4528, 3090, 0, 0, 0]
# y  [396, -428]
# state 3
# obstacles values [4201, 0, 0, 0, 0]
# y  [360, -376]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [0, 0, 0, 4516, 4713]
# y  [-260, 332]
# state 3
# obstacles values [0, 0, 0, 4487, 4609]
# y  [-340, 388]
# state 3
# obstacles values [0, 0, 0, 1165, 4707]
# y  [-348, 356]
# state 3
# obstacles values [0, 0, 0, 0, 4568]
# y  [-144, 136]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [3510, 3290, 0, 0, 0]
# y  [280, -200]
# state 3
# obstacles values [3679, 3307, 0, 0, 0]
# y  [280, -208]
# state 3
# obstacles values [3572, 2620, 0, 0, 0]
# y  [272, -248]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# change state to local
# state 3
# obstacles values [2149, 3598, 0, 0, 0]
# y  [40, -120]
# state 3
# obstacles values [0, 2071, 4222, 0, 0]
# y  [-44, -172]
# state 3
# obstacles values [0, 1674, 4054, 0, 0]
# y  [-60, -196]
# state 3
# obstacles values [0, 2843, 3426, 0, 0]
# y  [-28, -204]
# state 3
# obstacles values [0, 1928, 4068, 0, 0]
# y  [-156, -92]
# state 3
# obstacles values [0, 0, 4020, 3047, 0]
# y  [-224, -80]
# state 3
# obstacles values [0, 0, 4151, 0, 0]
# y  [-180, -140]
# state 3
# obstacles values [0, 0, 3646, 2194, 0]
# y  [-208, -80]
# state 3
# obstacles values [0, 0, 2814, 3009, 0]
# y  [-208, -80]
# state 3
# obstacles values [0, 0, 3406, 0, 0]
# y  [-168, -112]
# state 3
# obstacles values [0, 0, 2988, 2214, 0]
# y  [-172, -60]
# state 3
# obstacles values [0, 0, 0, 3273, 1967]
# y  [-232, 112]
# state 3
# obstacles values [0, 0, 3797, 2304, 0]
# y  [-216, -16]
# state 3
# obstacles values [0, 0, 3990, 0, 0]
# y  [-176, -80]
# state 3
# obstacles values [0, 0, 4114, 1827, 0]
# y  [-228, -76]
# state 3
# obstacles values [0, 0, 3101, 3822, 0]
# y  [-344, 208]
# state 3
# obstacles values [0, 0, 0, 0, 3891]
# y  [-288, 184]
# state 3
# obstacles values [0, 0, 0, 0, 4020]
# y  [-320, 232]
# state 3
# obstacles values [0, 0, 0, 1573, 4124]
# y  [-348, 284]
# state 3
# obstacles values [0, 0, 0, 2421, 3746]
# y  [-324, 284]
# state 3
# obstacles values [0, 0, 0, 2534, 2403]
# y  [-308, 284]
# change state to global
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# state 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-bab946236806> in <module>
#      71         """
#      72         y = [100,100]
# ---> 73         ctrl.set_motors(y[0],y[1],node)
#      74
#      75     elif state == 3:
#
# ~/Documents/Mobile Robotics/EPFL_MobileRobotics_2021/control.py in set_motors(left, right, node)
#      38 #middle level functions
#      39 def set_motors(left,right,node):
# ---> 40     aw(node.set_variables(motors(left,right)))
#      41
#      42 def stopmotors(node):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tdmclient/clientasync.py in aw(co)
#     166             r = await co
#     167
# --> 168         ClientAsync.run_async_program(prog)
#     169         return r
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tdmclient/clientasync.py in run_async_program(prog)
#     151         try:
#     152             while True:
# --> 153                 co.send(None)
#     154         except StopIteration:
#     155             pass
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tdmclient/clientasync.py in prog()
#     164         async def prog():
#     165             nonlocal r
# --> 166             r = await co
#     167
#     168         ClientAsync.run_async_program(prog)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tdmclient/clientasyncnode.py in set_variables(self, var_dict)
#      93     @types.coroutine
#      94     def set_variables(self, var_dict):
# ---> 95         result = yield from self.thymio.send_msg_and_get_result(
#      96             lambda notify:
#      97                 self.send_set_variables(var_dict, request_id_notify=notify)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tdmclient/clientasync.py in send_msg_and_get_result(self, send_fun)
#     128         while not done:
#     129             yield
# --> 130             sleep(self.DEFAULT_SLEEP)
#     131             self.process_waiting_messages()
#     132         return result
#
# KeyboardInterrupt:

# %%
ctrl.stopmotors(node)
