# %% [markdown]
# Boucle globale de lecture de vidéo
#
#
# state= 0
#     img_calibration
#     obstacle detection
#     start and goal
#     global_nav
#
# state = 1
#     img_calibration
#     detect Thymio
#     astolfi ou local nav

# %%
#lancer la communication asynchrone avec thymio
from tdmclient import ClientAsync, aw
client = ClientAsync()
node = await client.wait_for_node()
await node.lock()

#vérifier d'avoir installer pyserial
# Out:
# Node eb16048f-962c-44b2-9651-cc3b67bca83b

# %% [markdown]
# # Initialisation

# %%
#check each import if it's really necessary
import cv2 
import time
import numpy as np
from PIL import Image 
import math
import matplotlib
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt

#import from global control
#import from glocal + control
import pyvisgraph as vg
import geopandas as gpd
from geopandas import GeoSeries
from shapely.geometry import Polygon, Point, LineString
import time

# %%
import Vision as vis
import Global as glob
import control as ctrl
import local_nav as local

# fonction et classe filtering
from kalman_step_astolfi import kalman_step_complet
from EKF_astolfi import ExtendedKalmanFilterAstolfi

# %%
#pour le test utilise une image mais en vrai relier à la caméra et temps réel

cap=cv2.VideoCapture(1,cv2.CAP_DSHOW)

for i in range (5):
    _, frame = cap.read()
    time.sleep(1)
    print("frame {}".format(i))

cap.release()


#img_final= cv2.flip(img_final, 0)
img_final2 = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
corner_coord=vis.find_corners(img_final2)
img=vis.img_calibration(img_final2,corner_coord)
#cv2.imwrite('warpped.png', zzz)
plt.figure()
plt.imshow(img)
plt.show()

# %%
#obstacle detection
polygons=vis.obstacle_detection(img)
#Start and goal detection
start=vis.detectCircle(img,'start')
goal=vis.detectCircle(img,'goal')

# %%
#plot the visibility graph

#a voir si on le met dedans
margin = 35
path=glob.global_pathplanning(start,goal,polygons,margin)

# %% [markdown]
# # Control and navigation loop

# %%
#cap=cv2.VideoCapture(0)

# %%
cap=cv2.VideoCapture(1,cv2.CAP_DSHOW)

for i in range (5):
    _, frame = cap.read()
    time.sleep(1)
    print("frame {}".format(i))

cap.release()
    
#frame=vis.img_calibration(frame)
    
plt.figure()
plt.imshow(frame)
plt.show()
# Out:
# frame 0
# frame 1
# frame 2
# frame 3
# frame 4

# %%
#img_final = cv2.imread(frame)
img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#img= cv2.flip(img, 0)
final=vis.img_calibration(img)
plt.figure()
plt.imshow(final)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_844/3487570615.py in <module>
#       2 img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#       3 #img= cv2.flip(img, 0)
# ----> 4 final=vis.img_calibration(img)
#       5 plt.figure()
#       6 plt.imshow(final)
#
# TypeError: img_calibration() missing 1 required positional argument: 'corner_coord'

# %%
def initialisation(pic):
    #obstacle detection
    polygons=vis.obstacle_detection(pic)
    #Start and goal detection
    start=vis.detectCircle(pic,'start')
    goal=vis.detectCircle(pic,'goal')
    init=[start,goal,polygons]
    return init

# %%
def printThymio(posThym, coordThym):
    coordThym.append((round(pos_thym[0]),round(pos_thym[1]))) #pos_thym = [x,y]
    for i in range(0,len(coordThym)):
        cv2.circle(final,(int(coordThym[i][0]),int(coordThym[i][1])), int(3), (0,255,255), 2)

# %%
def printThymioKalm(posThym, coordThym):    #la couleur de la trace change
    coordThym.append((round(pos_thym[0]),round(pos_thym[1]))) #pos_thym = [x,y]
    for i in range(0,len(coordThym)):
        cv2.circle(final,(int(coordThym[i][0]),int(coordThym[i][1])), int(3), (0,0,255), 2)

# %%
#convertir frame to real => mm/s vitesse et position

#coefficients for the Astolfi controller (distances in millimeter)
r=22
l=48 
kp=25  #2 #>0
ka=50  #must be > kp
kb=-0.0001 #<0

#coeff_commtoreal=0,38

#astolfi return to iterate on the next goal from the path list

def astolfi(actual_pos, goal_pos, actual_angle, node):
    #déplacer les variables à l'extérieur dans control
    switch_next=0
    thresh_close2=10
    thresh_close1=75
    comm_sat_min=100
    comm_sat_max=250
    
    delta=np.subtract(goal_pos,actual_pos)
    pho=np.sqrt(np.sum(np.square(delta)))
    alpha=-np.radians(actual_angle) + np.arctan2(-delta[1],delta[0])
    beta=-actual_angle-alpha
    v=kp*pho
    if(pho<thresh_close1):
        v=comm_sat_min*r
    if(pho<thresh_close2):
        v=0
        switch_next=1      
    omega=ka*alpha+kb*beta
    #omega=0
    right_speed=(l*omega+v)/r
    left_speed=(v-l*omega)/r
    left_speed=int(left_speed)
    right_speed=int(right_speed)
    ctrl.set_motors(left_speed, right_speed, node)
    return switch_next

# %%
def printGlobalPath(path, img):
    lineThickness = 3
    for i in range(0,len(path)-1):
        cv2.line(final, (round(path[i][0]), round(path[i][1])),(round(path[i+1][0]), round(path[i+1][1])), (0,255,0), lineThickness)

# %%
cap=cv2.VideoCapture(1,cv2.CAP_DSHOW)
for i in range (5):
    _, frame = cap.read()
    time.sleep(1)
    print("frame {}".format(i))

#cap.release()
#plt.figure()
#plt.imshow(frame)
#plt.show()

#time.sleep(1)
state=0
margin = 40
switch_next=0
path_iter=1
obst = [0,0,0]     # measurements from left, middle, right prox sensors
obstThrL = 2500      # low obstacle threshold to switch state 3->2
obstThrL2 = 3000
obstThrH = 4000      # high obstacle threshold to switch state 2->3 
y = [0,0]          # powers given to motor wheels

#init des variables Kalman, et visu de la trace
KF = ExtendedKalmanFilterAstolfi()
KF.init_state_vector(0,0,0,0,0,0,0,0)   #xxx a rendre plus joli
KF.set_time_stamp(time.time())

sensor_package = []
kalman_pos = []

coordThym = []
coordKalm = []

while (cap.isOpened()):
    _, frame = cap.read()
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    #final=vis.img_calibration(img, corner_coord)
    #img= cv2.flip(img, 0)
    if(state==0):
        corner_coord=vis.find_corners(img)
        final=vis.img_calibration(img, corner_coord)
        init=initialisation(final)
        path=glob.global_pathplanning(init[0],init[1],init[2],margin)
        state=2
    #if state==1:
     #   time.sleep(6)
      #  print("time sleep over")
       # _, frame1 = cap.read()
        #plt.figure()
        #plt.imshow(frame1)
        #plt.show()
        #img1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)
        #state=2
    if (state==2):
        final=vis.img_calibration(img, corner_coord)
        #plt.figure()
        #plt.imshow(final1)
        #plt.show()
        pos_thym=vis.detectThymio(final)[0]
        angle_thym=vis.directionThymio(final)
        
        vit_roue_droite = ctrl.read_motors_speed(node,client)[0]#xxx droite ou gauche a verifier
        vit_roue_gauche = ctrl.read_motors_speed(node,client)[1]#droite ou gauche a verifier
        sensor_package = [pos_thym[0], pos_thym[1], angle_thym, vit_roue_droite, vit_roue_gauche]
        E = kalman_step_complet(sensor_package,KF)
        kalman_pos = [E[0], E[1]]
        
        #print(pos_thym)
        #print(angle_thym)
        #y = [50,50]
        #ctrl.set_motors(y[0],y[1],node)
        switch_next=astolfi(pos_thym,path[path_iter],angle_thym,node)
        if(switch_next==1):
            path_iter=path_iter+1
            print("path iter ",path_iter)
            if(path_iter==len(path)):
                ctrl.stopmotors(node)
                print("finish")
                state=4
                
        #local avoidance
        # get the proximity sensors values and obstacle update
        #prox_horizontal = ctrl.read_prox_sensors(node,client)
        #obst = [prox_horizontal[0], prox_horizontal[2], prox_horizontal[4]]
        # update the state and speed motors values
        #state = local.update_state(state,obstThrL,obstThrH, obst)  
    if(state==3):
        print("local_nav")
        prox_horizontal = ctrl.read_prox_sensors(node,client)
        obst = [prox_horizontal[0], prox_horizontal[2], prox_horizontal[4]]
        state = local.update_state(state,obstThrL,obstThrH, obst)
        print("obstacles values", obst)
        y = local.local_nav(prox_horizontal,y)
        print("y ",y)
        ctrl.set_motors(y[0],y[1],node)
    if state==4:
        break
    vis.printGlobalPath(path, final)
   # printThymio(pos_thym, coordThym)
    printThymioKalm(kalman_pos,coordKalm)
    cv2.imshow("results", final)
    if cv2.waitKey(1) & 0xFF ==ord('q'):
        break
        
cap.release()
#cv2.destroyAllWindows()
# Out:
# frame 0
# frame 1
# frame 2
# frame 3
# frame 4
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 50.07it/s]
# Visibility graph points:  [[Point(466.77, 205.55), Point(388.99, 326.79), Point(513.84, 393.84), Point(589.31, 274.91)], [Point(265.61, 194.97), Point(107.63, 199.02), Point(109.38, 383.51), Point(267.37, 381.49)], [Point(357.53, -26.72), Point(259.51, 73.64), Point(368.47, 166.72), Point(466.49, 66.36)], [Point(-8.52, -26.00), Point(-6.47, 131.72), Point(182.48, 128.29), Point(184.54, -26.00)]]
#
# Shortest path distance: 641.4380175965474
#
# 0    POLYGON ((466.768 205.547, 388.991 326.787, 51...
# 1    POLYGON ((265.615 194.971, 107.627 199.022, 10...
# 2    POLYGON ((357.529 -26.716, 259.505 73.641, 368...
# 3    POLYGON ((-8.523 -26.000, -6.474 131.724, 182....
# 0                               POINT (48.004 327.169)
# 1                              POINT (107.627 199.022)
# 2                              POINT (368.471 166.716)
# 3                               POINT (559.637 26.185)
# dtype: geometry
# path  0     POINT (48.004 327.169)
# 1    POINT (107.627 199.022)
# 2    POINT (368.471 166.716)
# 3     POINT (559.637 26.185)
# dtype: geometry
# 2
# 2
# temps entre samples:  0.7184598445892334
# 2
# 2
# temps entre samples:  0.375931978225708
# 2
# 2
# temps entre samples:  0.14805984497070312
# 2
# 2
# temps entre samples:  0.1568915843963623
# 2
# 2
# temps entre samples:  0.17732834815979004
# 2
# 2
# temps entre samples:  0.1848316192626953
# 2
# 2
# temps entre samples:  0.18488860130310059
# 2
# 2
# temps entre samples:  0.15849757194519043
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.1929490566253662
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.18361258506774902
# 2
# 2
# temps entre samples:  0.18620896339416504
# 2
# 2
# temps entre samples:  0.16059494018554688
# 2
# 2
# temps entre samples:  0.18572521209716797
# 2
# 2
# temps entre samples:  0.18842720985412598
# 2
# 2
# temps entre samples:  0.18030929565429688
# 2
# 2
# temps entre samples:  0.17418718338012695
# 2
# 2
# temps entre samples:  0.17569494247436523
# 2
# 2
# temps entre samples:  0.21693682670593262
# 2
# 2
# temps entre samples:  0.1694934368133545
# 2
# 2
# temps entre samples:  0.17851805686950684
# 2
# 2
# temps entre samples:  0.14799976348876953
# 2
# 2
# temps entre samples:  0.17339706420898438
# 2
# 2
# temps entre samples:  0.17272734642028809
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.1730821132659912
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.17571735382080078
# 2
# 2
# temps entre samples:  0.17180418968200684
# 2
# 2
# temps entre samples:  0.1718132495880127
# 2
# 2
# temps entre samples:  0.1664896011352539
# 2
# 2
# temps entre samples:  0.17458581924438477
# 2
# 2
# temps entre samples:  0.1647489070892334
# 2
# 2
# temps entre samples:  0.14572429656982422
# 2
# 2
# temps entre samples:  0.13919615745544434
# path iter  2
# 2
# 2
# temps entre samples:  0.17730164527893066
# 2
# 2
# temps entre samples:  0.16315603256225586
# 2
# 2
# temps entre samples:  0.17179179191589355
# 2
# 2
# temps entre samples:  0.16193103790283203
# 2
# 2
# temps entre samples:  0.16766929626464844
# 2
# 2
# temps entre samples:  0.17690491676330566
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.16625523567199707
# 2
# 2
# temps entre samples:  0.17415285110473633
# 2
# 2
# temps entre samples:  0.15939116477966309
# 2
# 2
# temps entre samples:  0.16563200950622559
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.1578981876373291
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15588998794555664
# 2
# 2
# temps entre samples:  0.16545391082763672
# 2
# 2
# temps entre samples:  0.16708707809448242
# 2
# 2
# temps entre samples:  0.16018366813659668
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.14556884765625
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.16040468215942383
# 2
# 2
# temps entre samples:  0.140655517578125
# 2
# 2
# temps entre samples:  0.14174723625183105
# 2
# 2
# temps entre samples:  0.16156816482543945
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15558767318725586
# 2
# 2
# temps entre samples:  0.1568443775177002
# 2
# 2
# temps entre samples:  0.14768290519714355
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.14269089698791504
# 2
# 2
# temps entre samples:  0.15646147727966309
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15857791900634766
# 2
# 2
# temps entre samples:  0.15493321418762207
# 2
# 2
# temps entre samples:  0.13511013984680176
# 2
# 2
# temps entre samples:  0.14461731910705566
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.1446094512939453
# 2
# 2
# temps entre samples:  0.1561262607574463
# 2
# 2
# temps entre samples:  0.15727949142456055
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15558195114135742
# 2
# 2
# temps entre samples:  0.15558624267578125
# 2
# 2
# temps entre samples:  0.15558338165283203
# 2
# 2
# temps entre samples:  0.15539288520812988
# 2
# 2
# temps entre samples:  0.16083502769470215
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15658140182495117
# 2
# 2
# temps entre samples:  0.14664506912231445
# 2
# 2
# temps entre samples:  0.16184759140014648
# 2
# 2
# temps entre samples:  0.17491436004638672
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15319538116455078
# 2
# 2
# temps entre samples:  0.15645051002502441
# 2
# 2
# temps entre samples:  0.15065550804138184
# 2
# 2
# temps entre samples:  0.15516161918640137
# 2
# 2
# temps entre samples:  0.14960527420043945
# 2
# 2
# temps entre samples:  0.15159249305725098
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15990185737609863
# 2
# 2
# temps entre samples:  0.14861416816711426
# 2
# 2
# temps entre samples:  0.16624832153320312
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15103673934936523
# 2
# 2
# temps entre samples:  0.16153788566589355
# 2
# 2
# temps entre samples:  0.15031838417053223
# 2
# 2
# temps entre samples:  0.16154909133911133
# 2
# 2
# temps entre samples:  0.1487419605255127
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.16358542442321777
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15166783332824707
# 2
# 2
# temps entre samples:  0.16071653366088867
# 2
# 2
# temps entre samples:  0.1476435661315918
# 2
# 2
# temps entre samples:  0.15920209884643555
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.1418781280517578
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15628552436828613
# 2
# 2
# temps entre samples:  0.15558409690856934
# 2
# 2
# temps entre samples:  0.15511465072631836
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15858078002929688
# path iter  3
# 2
# 2
# temps entre samples:  0.15943622589111328
# 2
# 2
# temps entre samples:  0.14855718612670898
# 2
# 2
# temps entre samples:  0.15563440322875977
# 2
# 2
# temps entre samples:  0.14638900756835938
# 2
# 2
# temps entre samples:  0.1607663631439209
# 2
# 2
# temps entre samples:  0.1477525234222412
# 2
# 2
# temps entre samples:  0.15943026542663574
# 2
# 2
# temps entre samples:  0.15340638160705566
# 2
# 2
# temps entre samples:  0.14433598518371582
# 2
# 2
# temps entre samples:  0.1602926254272461
# 2
# 2
# temps entre samples:  0.15612363815307617
# 2
# 2
# temps entre samples:  0.1569056510925293
# 2
# 2
# temps entre samples:  0.15478157997131348
# 2
# 2
# temps entre samples:  0.15169310569763184
# 2
# 2
# temps entre samples:  0.1456773281097412
# 2
# 2
# temps entre samples:  0.17063283920288086
# 2
# 2
# temps entre samples:  0.14893341064453125
# 2
# 2
# temps entre samples:  0.1567995548248291
# 2
# 2
# temps entre samples:  0.16353940963745117
# 2
# 2
# temps entre samples:  0.15095806121826172
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.1629161834716797
# 2
# 2
# temps entre samples:  0.14562702178955078
# 2
# 2
# temps entre samples:  0.1655116081237793
# 2
# 2
# temps entre samples:  0.14925885200500488
# 2
# 2
# temps entre samples:  0.1645505428314209
# 2
# 2
# temps entre samples:  0.15611767768859863
# 2
# 2
# temps entre samples:  0.14913368225097656
# 2
# 2
# temps entre samples:  0.16228795051574707
# 2
# 2
# temps entre samples:  0.15256142616271973
# 2
# 2
# temps entre samples:  0.15788674354553223
# 2
# 2
# temps entre samples:  0.1565852165222168
# 2
# 2
# temps entre samples:  0.15057921409606934
# 2
# 2
# temps entre samples:  0.1600639820098877
# 2
# 2
# temps entre samples:  0.15587997436523438
# 2
# 2
# temps entre samples:  0.15757989883422852
# 2
# 2
# temps entre samples:  0.1538252830505371
# 2
# 2
# temps entre samples:  0.15261363983154297
# 2
# 2
# temps entre samples:  0.16514015197753906
# 2
# 2
# temps entre samples:  0.1500837802886963
# 2
# 2
# temps entre samples:  0.1545863151550293
# 2
# 2
# temps entre samples:  0.15761828422546387
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15662574768066406
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.16024279594421387
# 2
# 2
# temps entre samples:  0.14860272407531738
# 2
# 2
# temps entre samples:  0.16303539276123047
# 2
# 2
# temps entre samples:  0.1576550006866455
# 2
# 2
# temps entre samples:  0.15273189544677734
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.1541273593902588
# 2
# 2
# temps entre samples:  0.14409494400024414
# 2
# 2
# temps entre samples:  0.15087413787841797
# 2
# 2
# temps entre samples:  0.16261935234069824
# 2
# 2
# temps entre samples:  0.15926313400268555
# 2
# 2
# temps entre samples:  0.1501753330230713
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.15554070472717285
# 2
# 2
# temps entre samples:  0.1537330150604248
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.1655571460723877
# 2
# 2
# temps entre samples:  0.1482405662536621
# failure in identifying corners
# 2
# 2
# temps entre samples:  0.1484062671661377
# 2
# 2
# temps entre samples:  0.15090608596801758
# 2
# 2
# temps entre samples:  0.15573334693908691
# 2
# 2
# temps entre samples:  0.15407919883728027
# 2
# 2
# temps entre samples:  0.14461278915405273
# path iter  4
# finish

# %%
ctrl.stopmotors(node)

# %%
def detectThymio(imgRGB):
    pts=[]
    #p1 is the big circle and p2 the little
    p1=[]
    p2=[]
    lower=np.array([10,30,30])
    upper=np.array([40,255,255])
    nb_iterations=1
    img_hsv = cv2.cvtColor(imgRGB, cv2.COLOR_RGB2HSV)
    mask = cv2.inRange(img_hsv, lower, upper)
    img_hsv = cv2.blur(img_hsv,(7,7))
    mask = cv2.erode(mask, None, iterations = nb_iterations)
    mask = cv2.dilate(mask, None, iterations = nb_iterations)
    elements,_ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    print(len(elements))
    if len(elements) > 0:
        #sorting the detected contours by descending area size
        elements.sort(key=cv2.contourArea, reverse=True)
        #finding big circle
        c=elements[0]
        ((x,y),rayon) = cv2.minEnclosingCircle(c)
        #finding little circle
        c2=elements[1]
        ((x2,y2),rayon2) = cv2.minEnclosingCircle(c2)
        p1=[x,y]
        p2=[x2,y2]
        pts=[p1,p2]
    return pts

#print(detectThymio(final))
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
corner_coord=vis.find_corners(frame)
final=vis.img_calibration(frame, corner_coord)
print(detectThymio(final)[0])

# %%
print(init)
# Out:
# [[112.5, 369.5], [0, 0], [[(253, 285), (298, 291), (283, 374), (238, 368)], [(180, 161), (186, 213), (124, 224), (120, 171)], [(382, 139), (439, 144), (436, 199), (377, 193)]]]

# %%
# Navigation initialisation
checkp=1           # goal checkpoint
actual_angle=0     # angle to xy axis
y = [0,0]          # powers given to motor wheels

# FSM initialisation
state = 0          # States FSM 0=global nav, 1=local nav
obst = [0,0,0]     # measurements from left, middle, right prox sensors
obstThrL = 2500      # low obstacle threshold to switch state 1->0
obstThrL2 = 3000
obstThrH = 4000      # high obstacle threshold to switch state 0->1  

while True:
    
    # get the proximity sensors values and obstacle update
    prox_horizontal = ctrl.read_prox_sensors(node,client)
    obst = [prox_horizontal[0], prox_horizontal[2], prox_horizontal[4]]
    
    # update the state and speed motors values
    state = local.update_state(state,obstThrL,obstThrH, obst)
    y = ctrl.read_motors_speed(node,client)
    
    print("state", state)

    if state == 0:
        
        """
        # With positon estimation when vision and/or kalman ready
        
        actual,angle = getting_vis()
        pred_pos,pred_angle = kalman(actual, angle)
        
        actual_pos=pred_pos
        actual_angle=pred_angle
        
        if actual_pos == checkpoints[checkp]: # other option: if (actual_pos - checkpoints[checkp]) < error
            checkp=checkp+1
        goal_pos=checkpoints[checkp]
        
        y = ctrl.astolfi2(actual_pos, goal_pos, actual_angle, node)
        
        """
        y = [50,50]
        ctrl.set_motors(y[0],y[1],node)

    elif state == 1:
        print("obstacles values", obst)
        y = local.local_nav(prox_horizontal,y)
        print("y ",y)
        ctrl.set_motors(y[0],y[1],node)

ctrl.stopmotors(node)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10532/435734342.py in <module>
#      14
#      15     # get the proximity sensors values and obstacle update
# ---> 16     prox_horizontal = ctrl.read_prox_sensors(node,client)
#      17     obst = [prox_horizontal[0], prox_horizontal[2], prox_horizontal[4]]
#      18
#
# NameError: name 'node' is not defined

# %%
ctrl.stopmotors(node)
