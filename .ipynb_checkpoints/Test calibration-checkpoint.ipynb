# %%
import cv2, time
import matplotlib.pyplot as plt
import numpy as np
import Vision as vis

# %%
cap = cv2.VideoCapture(0)

# %%
env = vis.takePicture()

# %%
def color_mask(imgRGB, color):
    img_hsv = cv2.cvtColor(imgRGB, cv2.COLOR_RGB2HSV)

    if color == 'red':
        mask = cv2.inRange(img_hsv, lower_red, upper_red)
    if color == 'green':
        mask = cv2.inRange(img_hsv, lower_green, upper_green)
    if color == 'cyan':
        mask = cv2.inRange(img_hsv, lower_cyan, upper_cyan)
    if color == 'pink':
        mask = cv2.inRange(img_hsv, lower_cyan, upper_cyan)
        
    output_hsv = img_hsv.copy()
    output_hsv[np.where(mask==0)] = 0
    
    return output_hsv

# %%
lower_green=np.array([30,40,40]) #only one that we tested
upper_green=np.array([70,255,255])
output = color_mask(env, 'green')
plt.figure()
plt.imshow(output)
plt.show()

# %%
new_env = vis.img_calibration(env)
plt.figure()
plt.imshow(new_env)
plt.show()
# Out:
# 4

# %%
env2 = vis.takePicture()

# %%
new_env2 = vis.img_calibration(env2)
plt.figure()
plt.imshow(new_env2)
plt.show()
# Out:
# 4

# %%
env3 = vis.takePicture()

# %%
new_env3 = vis.img_calibration(env3)
plt.figure()
plt.imshow(new_env3)
plt.show()
# Out:
# 4

# %%
cap = cv2.VideoCapture(0)

# %%
a = 0
coord = []
x = 0
y = 0
while True:
    a = a + 1
    _, frame = cap.read()
    cv2.imwrite('test.png',frame)
    print('la')
    frame = vis.img_calibration(frame)
    
    #Show result 
    cv2.imshow("results", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):      
        break
        
    
  
cap.release() 
  
cv2.destroyAllWindows()
# Out:
# 0
# la
# 4
# 4
# 1
# la
# 4
# 4
# 2
# la
# 4
# 4
# 3
# la
# 4
# 4
# 4
# la
# 4
# 4
# 5
# la
# 4
# 4
# 6
# la
# 4
# 4
# 7
# la
# 4
# 4
# 8
# la
# 4
# 4
# 9
# la
# 4
# 4
# 10
# la
# 4
# 4
# 11
# la
# 4
# 4
# 12
# la
# 4
# 4
# 13
# la
# 4
# 4
# 14
# la
# 4
# 4
# 15
# la
# 4
# 4
# 16
# la
# 4
# 4
# 17
# la
# 4
# 4
# 18
# la
# 4
# 4
# 19
# la
# 4
# 4
# 20
# la
# 4
# 4

# %%
test = cv2.imread('test.png')
new_test = vis.img_calibration(test)
plt.figure()
plt.imshow(new_env3)
plt.show()
# Out:
# 0
# 0
# failure in identifying corners
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/7t/0nrx2cz904vd8vf6qt5jttqm0000gn/T/ipykernel_27497/2185387584.py in <module>
#       1 test = cv2.imread('test.png')
# ----> 2 new_test = vis.img_calibration(test)
#       3 plt.figure()
#       4 plt.imshow(new_env3)
#       5 plt.show()
#
# ~/Documents/MA1/BMR/EPFL_MobileRobotics_2021/Vision.py in img_calibration(img)
#     203         print("failure in identifying corners")
#     204         print(corner_points)
# --> 205     corner_points=order_points(corner_points)
#     206     warpedimg=four_point_transform(img,corner_points)
#     207     return warpedimg
#
# ~/Documents/MA1/BMR/EPFL_MobileRobotics_2021/Vision.py in order_points(pts)
#      64     pts=sorted(pts, key=lambda x: (int(x[1]), int(x[0]))) #topleft,topright,bottomleft,bottomright
#      65     #top left x > top right x => erreur et intervertit
# ---> 66     if pts[0][0] > pts[1][0]:
#      67         pts[0], pts[1] = pts[1], pts[0]
#      68     if pts[2][0] > pts[3][0]:
#
# IndexError: list index out of range
