# %% [markdown]
# Boucle globale de lecture de vidéo
#
#
# state= 0
#     img_calibration
#     obstacle detection
#     start and goal
#     global_nav
#
# state = 1
#     img_calibration
#     detect Thymio
#     astolfi ou local nav

# %%
#lancer la communication asynchrone avec thymio
from tdmclient import ClientAsync, aw
client = ClientAsync()
node = await client.wait_for_node()
await node.lock()

#vérifier d'avoir installer pyserial
# Out:
# Node eb16048f-962c-44b2-9651-cc3b67bca83b

# %% [markdown]
# # Initialisation

# %%
#check each import if it's really necessary
import cv2 
import time
import numpy as np
from PIL import Image 
import math
import matplotlib
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt

#import from global control
#import from glocal + control
import pyvisgraph as vg
import geopandas as gpd
from geopandas import GeoSeries
from shapely.geometry import Polygon, Point, LineString
import time

# %%
import Vision as vis
import Global as glob
import control as ctrl
import local_nav as local

# fonction et classe filtering
from kalman_step_astolfi import kalman_step_complet
from EKF_astolfi import ExtendedKalmanFilterAstolfi

# %%
#pour le test utilise une image mais en vrai relier à la caméra et temps réel

cap=cv2.VideoCapture(1,cv2.CAP_DSHOW)

for i in range (5):
    _, frame = cap.read()
    time.sleep(1)
    print("frame {}".format(i))

cap.release()


#img_final= cv2.flip(img_final, 0)
img_final2 = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
corner_coord=vis.find_corners(img_final2)
img=vis.img_calibration(img_final2,corner_coord)
#cv2.imwrite('warpped.png', zzz)
plt.figure()
plt.imshow(img)
plt.show()
# Out:
# frame 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19136/1392778362.py in <module>
#       5 for i in range (5):
#       6     _, frame = cap.read()
# ----> 7     time.sleep(1)
#       8     print("frame {}".format(i))
#       9
#
# KeyboardInterrupt:

# %%
#obstacle detection
polygons=vis.obstacle_detection(img)
#Start and goal detection
start=vis.detectCircle(img,'start')
goal=vis.detectCircle(img,'goal')

# %%
#plot the visibility graph

#a voir si on le met dedans
margin = 35
path=glob.global_pathplanning(start,goal,polygons,margin)

# %% [markdown]
# # Control and navigation loop

# %%
#cap=cv2.VideoCapture(0)

# %%
cap=cv2.VideoCapture(1,cv2.CAP_DSHOW)

for i in range (5):
    _, frame = cap.read()
    time.sleep(1)
    print("frame {}".format(i))

cap.release()
    
#frame=vis.img_calibration(frame)
    
plt.figure()
plt.imshow(frame)
plt.show()

# %%
#img_final = cv2.imread(frame)
img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#img= cv2.flip(img, 0)
final=vis.img_calibration(img)
plt.figure()
plt.imshow(final)
plt.show()

# %%
def initialisation(pic):
    #obstacle detection
    polygons=vis.obstacle_detection(pic)
    #Start and goal detection
    start=vis.detectCircle(pic,'start')
    goal=vis.detectCircle(pic,'goal')
    init=[start,goal,polygons]
    return init

# %%
def printThymio(posThym, coordThym):
    coordThym.append((round(pos_thym[0]),round(pos_thym[1]))) #pos_thym = [x,y]
    for i in range(0,len(coordThym)):
        cv2.circle(final,(int(coordThym[i][0]),int(coordThym[i][1])), int(3), (0,255,255), 2)

# %%
def printThymioKalm(posThym, coordThym):    #la couleur de la trace change
 #   print("print dans thymkalm")
 #   print(posThym[0])
 #   print("prochain round: ")
 #   print(round(posThym[0]))
    coordThym.append((round(posThym[0]),round(posThym[1]))) #pos_thym = [x,y]
    for i in range(0,len(coordThym)):
        cv2.circle(final,(int(coordThym[i][0]),int(coordThym[i][1])), int(3), (0,0,255), 2)

# %%
#convertir frame to real => mm/s vitesse et position

#coefficients for the Astolfi controller (distances in millimeter)
r=22
l=48 
kp=25  #2 #>0
ka=50  #must be > kp
kb=-0.0001 #<0

#coeff_commtoreal=0,38

#astolfi return to iterate on the next goal from the path list

def astolfi(actual_pos, goal_pos, actual_angle, node):
    #déplacer les variables à l'extérieur dans control
    switch_next=0
    thresh_close2=10
    thresh_close1=75
    comm_sat_min=100
    comm_sat_max=250
    
    delta=np.subtract(goal_pos,actual_pos)
    pho=np.sqrt(np.sum(np.square(delta)))
    alpha=-actual_angle + np.arctan2(-delta[1],delta[0])
    beta=-actual_angle-alpha
    v=kp*pho
    if(pho<thresh_close1):
        v=comm_sat_min*r
    if(pho<thresh_close2):
        v=0
        switch_next=1      
    omega=ka*alpha+kb*beta
    #omega=0
    right_speed=(l*omega+v)/r
    left_speed=(v-l*omega)/r
    left_speed=int(left_speed)
    right_speed=int(right_speed)
    ctrl.set_motors(left_speed, right_speed, node)
    return switch_next

# %%
def printGlobalPath(path, img):
    lineThickness = 3
    for i in range(0,len(path)-1):
        cv2.line(final, (round(path[i][0]), round(path[i][1])),(round(path[i+1][0]), round(path[i+1][1])), (0,255,0), lineThickness)

# %%
print(angle_thym)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16388/4020075655.py in <module>
# ----> 1 print(angle_thym)
#
# NameError: name 'angle_thym' is not defined

# %%
cap=cv2.VideoCapture(1,cv2.CAP_DSHOW)
for i in range (5):
    _, frame = cap.read()
    time.sleep(1)
    print("frame {}".format(i))

#cap.release()
#plt.figure()
#plt.imshow(frame)
#plt.show()

#time.sleep(1)
state=0
margin = 40
switch_next=0
path_iter=1
obst = [0,0,0]     # measurements from left, middle, right prox sensors
obstThrL = 2500      # low obstacle threshold to switch state 3->2
obstThrL2 = 3000
obstThrH = 4000      # high obstacle threshold to switch state 2->3 
y = [0,0]          # powers given to motor wheels

#init des variables Kalman, et visu de la trace
KF = ExtendedKalmanFilterAstolfi()
KF.set_time_stamp(time.time())

sensor_package = []
kalman_pos = []

coordThym = []
coordKalm = []

while (cap.isOpened()):
    _, frame = cap.read()
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    #final=vis.img_calibration(img, corner_coord)
    #img= cv2.flip(img, 0)
    if(state==0):
        corner_coord=vis.find_corners(img)
        final=vis.img_calibration(img, corner_coord)
        init=initialisation(final)
        path=glob.global_pathplanning(init[0],init[1],init[2],margin)
        
        init_pos = [init[0][0], init[0][1]]
        
        KF.init_state_vector(init_pos[0],init_pos[1],0,0,0,0,0,0)   #xxx a rendre plus joli
        angle_kalman = 0
        state=2
    #if state==1:
     #   time.sleep(6)
      #  print("time sleep over")
       # _, frame1 = cap.read()
        #plt.figure()
        #plt.imshow(frame1)
        #plt.show()
        #img1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)
        #state=2
    if (state==2):
        final=vis.img_calibration(img, corner_coord)
        #plt.figure()
        #plt.imshow(final1)
        #plt.show()
        pos_thym=vis.detectThymio(final)[0]
        angle_thym=vis.directionThymio(final)
        
        vit_roue_droite = ctrl.read_motors_speed(node,client)[1]#xxx droite ou gauche a verifier
        vit_roue_gauche = ctrl.read_motors_speed(node,client)[0]#droite ou gauche a verifier
        sensor_package = [pos_thym[0], pos_thym[1], angle_thym, vit_roue_droite, vit_roue_gauche]
 #       print(sensor_package)
#       a modifier (augmenter pour etre plus souple)
        if(bool(angle_thym)):
            if(abs(angle_thym-angle_kalman)>0.4):
                print("trop grande différence d'angle detectée")
                sensor_package = [None, None, None, vit_roue_droite, vit_roue_gauche]
            else:
                print("différence d'angle correcte")
        E = kalman_step_complet(sensor_package,KF)
        kalman_pos = [E[0], E[1]]
        kalman_pos = np.squeeze(np.asarray(kalman_pos))
 #       print("kalman pos: {}".format(kalman_pos))
        print("angle from camera: {}".format(sensor_package[2]))

        print(type(kalman_pos[0]))
        angle_kalman=E[2]
        angle_kalman = np.squeeze(np.asarray(angle_kalman[0]))
 #       print("kalman angle: {}".format(angle_kalman))
        
        #print(pos_thym)
        #print(angle_thym)
        y = [60,60]
        ctrl.set_motors(y[0],y[1],node)
        
    #    switch_next=astolfi(kalman_pos,path[path_iter],angle_kalman,node)
        if(switch_next==1):
            path_iter=path_iter+1
            print("path iter ",path_iter)
            if(path_iter==len(path)):
                ctrl.stopmotors(node)
                print("finish")
                state=4
                
        #local avoidance
        # get the proximity sensors values and obstacle update
        #prox_horizontal = ctrl.read_prox_sensors(node,client)
        #obst = [prox_horizontal[0], prox_horizontal[2], prox_horizontal[4]]
        # update the state and speed motors values
        #state = local.update_state(state,obstThrL,obstThrH, obst)  
    if(state==3):
   #     print("local_nav")
        prox_horizontal = ctrl.read_prox_sensors(node,client)
        obst = [prox_horizontal[0], prox_horizontal[2], prox_horizontal[4]]
        state = local.update_state(state,obstThrL,obstThrH, obst)
  #      print("obstacles values", obst)
        y = local.local_nav(prox_horizontal,y)
   #     print("y ",y)
        ctrl.set_motors(y[0],y[1],node)
    if state==4:
        break
    vis.printGlobalPath(path, final)
   # printThymio(pos_thym, coordThym)
 #   print(kalman_pos)
 #   print(coordKalm)
    printThymioKalm(kalman_pos,coordKalm)
    cv2.imshow("results", final)
    if cv2.waitKey(1) & 0xFF ==ord('q'):
        break
        
cap.release()
#cv2.destroyAllWindows()
# Out:
# frame 0
# frame 1
# frame 2
# frame 3
# frame 4
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.53it/s]
# Visibility graph points:  [[Point(386.32, 243.63), Point(388.69, 381.62), Point(532.68, 379.37), Point(530.31, 241.38)], [Point(343.79, -16.67), Point(234.60, 69.28), Point(325.99, 176.66), Point(439.77, 90.74)]]
#
# Shortest path distance: 527.9442761431466
#
# 0    POLYGON ((386.315 243.631, 388.694 381.619, 53...
# 1    POLYGON ((343.786 -16.675, 234.604 69.277, 325...
# 0                              POINT (103.040 343.553)
# 1                               POINT (541.290 49.169)
# dtype: geometry
#
# path  0    POINT (103.040 343.553)
# 1     POINT (541.290 49.169)
# dtype: geometry
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 0.0
# 0.0
# --------------------------------------------
# temps entre samples:  0.24950671195983887
# state avant predict
# [[103.03982544]
#  [343.55310059]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]]
# state apres predict
# [[103.03982544]
#  [343.55310059]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.043935694971434444
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 0.0
# 0.0
# --------------------------------------------
# temps entre samples:  0.1495978832244873
# state avant predict
# [[8.13834666e+01]
#  [2.81230411e+02]
#  [3.53620520e-02]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]]
# state apres predict
# [[8.13834666e+01]
#  [2.81230411e+02]
#  [3.53620520e-02]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.037627444923435845
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# -0.03908626039554964
# -0.03908827850150367
# --------------------------------------------
# temps entre samples:  0.14719939231872559
# state avant predict
# [[ 8.03498407e+01]
#  [ 2.78286347e+02]
#  [ 3.70947195e-02]
#  [-3.90862604e-02]
#  [-3.90882785e-02]
#  [-4.46432379e-02]
#  [ 1.57933486e-03]
#  [ 2.56267423e-08]]
# state apres predict
# [[ 8.03432692e+01]
#  [ 2.78286579e+02]
#  [ 3.70947233e-02]
#  [-3.90862604e-02]
#  [-3.90882785e-02]
#  [-3.90066077e-02]
#  [ 2.89853264e-03]
#  [ 2.24233995e-08]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.027678118212456273
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 2.5641019525535445
# 2.763110016475551
# --------------------------------------------
# temps entre samples:  0.13376402854919434
# state avant predict
# [[ 8.06108024e+01]
#  [ 2.77555403e+02]
#  [ 2.98866879e-02]
#  [ 2.56410195e+00]
#  [ 2.76311002e+00]
#  [ 1.72384290e+00]
#  [-6.25905614e-02]
#  [-1.44137224e-03]]
# state apres predict
# [[ 8.08413906e+01]
#  [ 2.77547030e+02]
#  [ 2.96938841e-02]
#  [ 2.56410195e+00]
#  [ 2.76311002e+00]
#  [ 2.66003767e+00]
#  [-1.59165321e-01]
#  [-2.21120071e-03]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.011475297931171028
# <class 'numpy.float64'>
# failure in identifying corners
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 4.742330367332409
# 5.1570798009285035
# --------------------------------------------
# temps entre samples:  0.14380383491516113
# state avant predict
# [[ 8.20196386e+01]
#  [ 2.77289473e+02]
#  [ 1.58386130e-02]
#  [ 4.74233037e+00]
#  [ 5.15707980e+00]
#  [ 4.21967073e+00]
#  [-1.96659258e-01]
#  [-3.81904043e-03]]
# state apres predict
# [[ 8.26264434e+01]
#  [ 2.77261193e+02]
#  [ 1.52894203e-02]
#  [ 4.74233037e+00]
#  [ 5.15707980e+00]
#  [ 4.94784261e+00]
#  [-1.56779816e-01]
#  [-4.60832704e-03]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.029621995652836085
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 6.261067796760054
# 6.828986597947171
# --------------------------------------------
# temps entre samples:  0.14570999145507812
# state avant predict
# [[ 8.32494966e+01]
#  [ 2.77735574e+02]
#  [ 2.30249197e-02]
#  [ 6.26106780e+00]
#  [ 6.82898660e+00]
#  [ 6.04552122e+00]
#  [-1.34189414e-01]
#  [-5.76404827e-03]]
# state apres predict
# [[ 8.41303894e+01]
#  [ 2.77716021e+02]
#  [ 2.21850402e-02]
#  [ 6.26106780e+00]
#  [ 6.82898660e+00]
#  [ 6.53982284e+00]
#  [-3.01344191e-01]
#  [-6.31020890e-03]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.0066498808073781794
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# Vitesses droite / gauche -------------------
# 8.409828062533144
# 9.155649040642478
# --------------------------------------------
# temps entre samples:  0.13527631759643555
# state avant predict
# [[ 8.41579148e+01]
#  [ 2.77269814e+02]
#  [ 1.51200823e-02]
#  [ 8.40982806e+00]
#  [ 9.15564904e+00]
#  [ 8.05918611e+00]
#  [-4.25408448e-01]
#  [-7.66121877e-03]]
# state apres predict
# [[ 8.52481318e+01]
#  [ 2.77212266e+02]
#  [ 1.40837008e-02]
#  [ 8.40982806e+00]
#  [ 9.15564904e+00]
#  [ 8.77972682e+00]
#  [-2.65571220e-01]
#  [-8.28689976e-03]]
# dans test de distance
# bonne distance detectee, update
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 8.52481318e+01]
#  [ 2.77212266e+02]
#  [ 1.40837008e-02]
#  [ 8.40982806e+00]
#  [ 9.15564904e+00]
#  [ 8.77972682e+00]
#  [-2.65571220e-01]
#  [-8.28689976e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 8.54908300e+01]
#  [ 2.77206804e+02]
#  [ 1.50122209e-02]
#  [ 1.25868289e+01]
#  [ 1.22452383e+01]
#  [ 1.12627499e+01]
#  [-3.04553076e-01]
#  [-9.09779298e-06]]
# angle from camera: -0.0
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 12.586828905127508
# 12.245238305811569
# --------------------------------------------
# temps entre samples:  0.14595866203308105
# state avant predict
# [[ 8.54908300e+01]
#  [ 2.77206804e+02]
#  [ 1.50122209e-02]
#  [ 1.25868289e+01]
#  [ 1.22452383e+01]
#  [ 1.12627499e+01]
#  [-3.04553076e-01]
#  [-9.09779298e-06]]
# state apres predict
# [[ 8.71347259e+01]
#  [ 2.77162352e+02]
#  [ 1.50108930e-02]
#  [ 1.25868289e+01]
#  [ 1.22452383e+01]
#  [ 1.24118365e+01]
#  [-3.72756474e-01]
#  [ 3.79545110e-03]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.049239094006896175
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 12.774012835486023
# 12.455155059828282
# --------------------------------------------
# temps entre samples:  0.13312077522277832
# state avant predict
# [[8.77396479e+01]
#  [2.78332905e+02]
#  [1.43420228e-02]
#  [1.27740128e+01]
#  [1.24551551e+01]
#  [1.25229336e+01]
#  [6.85047396e-01]
#  [3.68708287e-03]]
# state apres predict
# [[ 8.94067105e+01]
#  [ 2.78424099e+02]
#  [ 1.48328501e-02]
#  [ 1.27740128e+01]
#  [ 1.24551551e+01]
#  [ 1.26106919e+01]
#  [-3.61812492e-01]
#  [ 3.54286417e-03]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.028226350479657155
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 12.932158426679644
# 12.75327884085857
# --------------------------------------------
# temps entre samples:  0.1470174789428711
# state avant predict
# [[ 8.88724955e+01]
#  [ 2.77812970e+02]
#  [ 4.16939210e-02]
#  [ 1.29321584e+01]
#  [ 1.27532788e+01]
#  [ 1.27248825e+01]
#  [-1.10301622e+00]
#  [ 2.63339157e-03]]
# state apres predict
# [[ 9.07432756e+01]
#  [ 2.77650807e+02]
#  [ 4.20810756e-02]
#  [ 1.29321584e+01]
#  [ 1.27532788e+01]
#  [ 1.28092384e+01]
#  [-1.07030611e+00]
#  [ 1.98755095e-03]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.012621139037818373
# <class 'numpy.float64'>
# failure in identifying corners
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.251914753095505
# 13.124066561868808
# --------------------------------------------
# temps entre samples:  0.13679194450378418
# state avant predict
# [[ 9.03056217e+01]
#  [ 2.77636208e+02]
#  [ 2.00690348e-02]
#  [ 1.32519148e+01]
#  [ 1.31240666e+01]
#  [ 1.30209673e+01]
#  [-1.02945472e+00]
#  [ 1.62346909e-03]]
# state apres predict
# [[ 9.20867851e+01]
#  [ 2.77495387e+02]
#  [ 2.02911123e-02]
#  [ 1.32519148e+01]
#  [ 1.31240666e+01]
#  [ 1.31800236e+01]
#  [-5.29269422e-01]
#  [ 1.42053546e-03]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.041024965026257375
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.392994084554823
# 13.303212509910896
# --------------------------------------------
# temps entre samples:  0.14615464210510254
# state avant predict
# [[9.23581503e+01]
#  [2.78457008e+02]
#  [1.94293507e-02]
#  [1.33929941e+01]
#  [1.33032125e+01]
#  [1.33064909e+01]
#  [1.55564671e-01]
#  [1.14008349e-03]]
# state apres predict
# [[ 9.43029557e+01]
#  [ 2.78479744e+02]
#  [ 1.95959792e-02]
#  [ 1.33929941e+01]
#  [ 1.33032125e+01]
#  [ 1.33405453e+01]
#  [-5.18624693e-01]
#  [ 9.97573052e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.03687539068342736
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.472726566873302
# 13.410543604946191
# --------------------------------------------
# temps entre samples:  0.15160155296325684
# state avant predict
# [[ 9.41779646e+01]
#  [ 2.78018712e+02]
#  [ 4.06506507e-02]
#  [ 1.34727266e+01]
#  [ 1.34105436e+01]
#  [ 1.33921721e+01]
#  [-9.23329109e-01]
#  [ 7.89624913e-04]]
# state apres predict
# [[ 9.62082387e+01]
#  [ 2.77878734e+02]
#  [ 4.07703590e-02]
#  [ 1.34727266e+01]
#  [ 1.34105436e+01]
#  [ 1.34083248e+01]
#  [-1.09222054e+00]
#  [ 6.90921799e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.0032468409203780173
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.426652828576513
# 13.383889288375766
# --------------------------------------------
# temps entre samples:  0.13743948936462402
# state avant predict
# [[ 9.46387236e+01]
#  [ 2.77600568e+02]
#  [ 1.74035639e-02]
#  [ 1.34266528e+01]
#  [ 1.33838893e+01]
#  [ 1.33265110e+01]
#  [-1.24318617e+00]
#  [ 5.43029082e-04]]
# state apres predict
# [[ 9.64703124e+01]
#  [ 2.77429705e+02]
#  [ 1.74781976e-02]
#  [ 1.34266528e+01]
#  [ 1.33838893e+01]
#  [ 1.33991810e+01]
#  [-4.66551876e-01]
#  [ 4.75150447e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.050179894726366726
# <class 'numpy.float64'>
# failure in identifying corners
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.368763226256995
# 13.481365958527569
# --------------------------------------------
# temps entre samples:  0.148040771484375
# state avant predict
# [[ 9.65683559e+01]
#  [ 2.77870892e+02]
#  [ 3.46444158e-02]
#  [ 1.33687632e+01]
#  [ 1.34813660e+01]
#  [ 1.34197114e+01]
#  [-2.03277423e-01]
#  [-7.06066442e-04]]
# state apres predict
# [[ 9.85550203e+01]
#  [ 2.77840799e+02]
#  [ 3.45398892e-02]
#  [ 1.33687632e+01]
#  [ 1.34813660e+01]
#  [ 1.34008988e+01]
#  [-9.29834918e-01]
#  [-1.25114147e-03]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.015589955176580815
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.445413075421314
# 13.522918580334682
# --------------------------------------------
# temps entre samples:  0.13554906845092773
# state avant predict
# [[ 9.82646814e+01]
#  [ 2.77448276e+02]
#  [ 2.69317585e-02]
#  [ 1.34454131e+01]
#  [ 1.35229186e+01]
#  [ 1.34226956e+01]
#  [-1.19951991e+00]
#  [-9.84196888e-04]]
# state apres predict
# [[ 1.00084115e+02]
#  [ 2.77285682e+02]
#  [ 2.67983515e-02]
#  [ 1.34454131e+01]
#  [ 1.35229186e+01]
#  [ 1.34694968e+01]
#  [-7.26129004e-01]
#  [-8.61172277e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.026350147883721597
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.48322983741818
# 13.536478189639787
# --------------------------------------------
# temps entre samples:  0.14646649360656738
# state avant predict
# [[ 9.95480410e+01]
#  [ 2.77342932e+02]
#  [ 2.58498164e-02]
#  [ 1.34832298e+01]
#  [ 1.35364782e+01]
#  [ 1.34716587e+01]
#  [-6.97182289e-01]
#  [-6.76169552e-04]]
# state apres predict
# [[ 1.01521188e+02]
#  [ 2.77240818e+02]
#  [ 2.57507802e-02]
#  [ 1.34832298e+01]
#  [ 1.35364782e+01]
#  [ 1.34963141e+01]
#  [-6.98298928e-01]
#  [-5.91648358e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.047220245378744204
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.561837532315101
# 13.526891400819812
# --------------------------------------------
# temps entre samples:  0.1344451904296875
# state avant predict
# [[ 1.01783515e+02]
#  [ 2.77924286e+02]
#  [ 3.02238014e-02]
#  [ 1.35618375e+01]
#  [ 1.35268914e+01]
#  [ 1.35406013e+01]
#  [-2.01033743e-01]
#  [ 8.18556380e-05]]
# state apres predict
# [[ 1.03603983e+02]
#  [ 2.77897258e+02]
#  [ 3.02348065e-02]
#  [ 1.35618375e+01]
#  [ 1.35268914e+01]
#  [ 1.35258081e+01]
#  [-8.18475084e-01]
#  [ 3.88290350e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.01817981507297828
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.533522292727637
# 13.438213153970056
# --------------------------------------------
# temps entre samples:  0.14766263961791992
# state avant predict
# [[ 1.02589779e+02]
#  [ 2.77515769e+02]
#  [ 2.82009991e-02]
#  [ 1.35335223e+01]
#  [ 1.34382132e+01]
#  [ 1.34470595e+01]
#  [-1.10863643e+00]
#  [ 8.48370016e-04]]
# state apres predict
# [[ 1.04575407e+02]
#  [ 2.77352065e+02]
#  [ 2.83262717e-02]
#  [ 1.35335223e+01]
#  [ 1.34382132e+01]
#  [ 1.34697816e+01]
#  [-7.60428258e-01]
#  [ 1.05899043e-03]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.010673335397011376
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.420820621503132
# 13.42674678936645
# --------------------------------------------
# temps entre samples:  0.13709282875061035
# state avant predict
# [[ 1.03349708e+02]
#  [ 2.77777952e+02]
#  [ 8.34379946e-03]
#  [ 1.34208206e+01]
#  [ 1.34267468e+01]
#  [ 1.33971406e+01]
#  [-4.13285143e-01]
#  [ 2.86651837e-04]]
# state apres predict
# [[ 1.05186359e+02]
#  [ 2.77721293e+02]
#  [ 8.38309737e-03]
#  [ 1.34208206e+01]
#  [ 1.34267468e+01]
#  [ 1.34223819e+01]
#  [-2.24005520e-01]
#  [-6.58463096e-05]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.050918615936784366
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.590721477720232
# 13.59465196329809
# --------------------------------------------
# temps entre samples:  0.13712549209594727
# state avant predict
# [[ 1.05475611e+02]
#  [ 2.78057123e+02]
#  [ 3.46921936e-02]
#  [ 1.35907215e+01]
#  [ 1.35946520e+01]
#  [ 1.35476073e+01]
#  [-6.06741875e-02]
#  [-4.99109280e-05]]
# state apres predict
# [[ 1.07333334e+02]
#  [ 2.78048803e+02]
#  [ 3.46853496e-02]
#  [ 1.35907215e+01]
#  [ 1.35946520e+01]
#  [ 1.35681516e+01]
#  [-9.42741910e-01]
#  [-4.36720620e-05]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.026062346388276758
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.620391700981246
# 13.551699272753975
# --------------------------------------------
# temps entre samples:  0.14505267143249512
# state avant predict
# [[ 1.07357992e+02]
#  [ 2.78008025e+02]
#  [ 2.88819686e-02]
#  [ 1.36203917e+01]
#  [ 1.35516993e+01]
#  [ 1.35639784e+01]
#  [-9.54077293e-01]
#  [ 5.10380041e-04]]
# state apres predict
# [[ 1.09325483e+02]
#  [ 2.77869633e+02]
#  [ 2.89560006e-02]
#  [ 1.36203917e+01]
#  [ 1.35516993e+01]
#  [ 1.35690479e+01]
#  [-7.84565279e-01]
#  [ 7.63249203e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.02313991747948275
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.5710789365381
# 13.595396714684375
# --------------------------------------------
# temps entre samples:  0.13745975494384766
# state avant predict
# [[ 1.09361342e+02]
#  [ 2.77438784e+02]
#  [ 3.18659731e-02]
#  [ 1.35710789e+01]
#  [ 1.35953967e+01]
#  [ 1.35592457e+01]
#  [-1.11190877e+00]
#  [ 5.31075791e-05]]
# state apres predict
# [[ 1.11225192e+02]
#  [ 2.77285941e+02]
#  [ 3.18732733e-02]
#  [ 1.35710789e+01]
#  [ 1.35953967e+01]
#  [ 1.35625513e+01]
#  [-8.65393187e-01]
#  [-2.70197535e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.028709823170149057
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.510200876461504
# 13.526925259300969
# --------------------------------------------
# temps entre samples:  0.14621400833129883
# state avant predict
# [[ 1.10861409e+02]
#  [ 2.77194277e+02]
#  [ 3.12590291e-02]
#  [ 1.35102009e+01]
#  [ 1.35269253e+01]
#  [ 1.35050584e+01]
#  [-9.37519210e-01]
#  [-2.12373115e-04]]
# state apres predict
# [[ 1.12836038e+02]
#  [ 2.77057199e+02]
#  [ 3.12279772e-02]
#  [ 1.35102009e+01]
#  [ 1.35269253e+01]
#  [ 1.34987517e+01]
#  [-8.44879059e-01]
#  [-1.85826476e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.05449145624073119
# <class 'numpy.float64'>
# elements:  1
# elements:  1
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.51528284500461
# 13.455762344437986
# --------------------------------------------
# temps entre samples:  0.1368424892425537
# state avant predict
# [[ 1.12064380e+02]
#  [ 2.74116215e+02]
#  [ 9.96394673e-02]
#  [ 1.35152828e+01]
#  [ 1.34557623e+01]
#  [ 1.33790493e+01]
#  [-3.24799027e+00]
#  [ 3.93911118e-04]]
# state apres predict
# [[ 1.13895202e+02]
#  [ 2.73671752e+02]
#  [ 9.96933710e-02]
#  [ 1.35152828e+01]
#  [ 1.34557623e+01]
#  [ 1.32849725e+01]
#  [-2.67849374e+00]
#  [ 6.61338895e-04]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.13895202e+02]
#  [ 2.73671752e+02]
#  [ 9.96933710e-02]
#  [ 1.35152828e+01]
#  [ 1.34557623e+01]
#  [ 1.32849725e+01]
#  [-2.67849374e+00]
#  [ 6.61338895e-04]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.13887572e+02]
#  [ 2.73671989e+02]
#  [ 9.95028654e-02]
#  [ 1.32936315e+01]
#  [ 1.34530529e+01]
#  [ 1.32085604e+01]
#  [-2.67040085e+00]
#  [-1.00936476e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  1
# elements:  1
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.29363152863203
# 13.45305294275811
# --------------------------------------------
# temps entre samples:  0.13484597206115723
# state avant predict
# [[ 1.13887572e+02]
#  [ 2.73671989e+02]
#  [ 9.95028654e-02]
#  [ 1.32936315e+01]
#  [ 1.34530529e+01]
#  [ 1.32085604e+01]
#  [-2.67040085e+00]
#  [-1.00936476e-03]]
# state apres predict
# [[ 1.15668693e+02]
#  [ 2.73311896e+02]
#  [ 9.93667567e-02]
#  [ 1.32936315e+01]
#  [ 1.34530529e+01]
#  [ 1.31750046e+01]
#  [-2.65259501e+00]
#  [-1.77134905e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.15668693e+02]
#  [ 2.73311896e+02]
#  [ 9.93667567e-02]
#  [ 1.32936315e+01]
#  [ 1.34530529e+01]
#  [ 1.31750046e+01]
#  [-2.65259501e+00]
#  [-1.77134905e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.15667137e+02]
#  [ 2.73312011e+02]
#  [ 9.93308432e-02]
#  [ 1.32492202e+01]
#  [ 1.34523862e+01]
#  [ 1.31653388e+01]
#  [-2.65140889e+00]
#  [-1.98146729e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  1
# elements:  1
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.249220156850116
# 13.452386185053205
# --------------------------------------------
# temps entre samples:  0.14550471305847168
# state avant predict
# [[ 1.15667137e+02]
#  [ 2.73312011e+02]
#  [ 9.93308432e-02]
#  [ 1.32492202e+01]
#  [ 1.34523862e+01]
#  [ 1.31653388e+01]
#  [-2.65140889e+00]
#  [-1.98146729e-03]]
# state apres predict
# [[ 1.17582756e+02]
#  [ 2.72926219e+02]
#  [ 9.90425304e-02]
#  [ 1.32492202e+01]
#  [ 1.34523862e+01]
#  [ 1.31534829e+01]
#  [-2.64357647e+00]
#  [-2.25740031e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.17582756e+02]
#  [ 2.72926219e+02]
#  [ 9.90425304e-02]
#  [ 1.32492202e+01]
#  [ 1.34523862e+01]
#  [ 1.31534829e+01]
#  [-2.64357647e+00]
#  [-2.25740031e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.17585981e+02]
#  [ 2.72925997e+02]
#  [ 9.89497179e-02]
#  [ 1.32335588e+01]
#  [ 1.35937112e+01]
#  [ 1.31778954e+01]
#  [-2.64533744e+00]
#  [-2.93672071e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  1
# elements:  1
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.233558770990628
# 13.593711202890068
# --------------------------------------------
# temps entre samples:  0.1376934051513672
# state avant predict
# [[ 1.17585981e+02]
#  [ 2.72925997e+02]
#  [ 9.89497179e-02]
#  [ 1.32335588e+01]
#  [ 1.35937112e+01]
#  [ 1.31778954e+01]
#  [-2.64533744e+00]
#  [-2.93672071e-03]]
# state apres predict
# [[ 1.19400490e+02]
#  [ 2.72561752e+02]
#  [ 9.85453509e-02]
#  [ 1.32335588e+01]
#  [ 1.35937112e+01]
#  [ 1.32169025e+01]
#  [-2.64589355e+00]
#  [-4.00169369e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.19400490e+02]
#  [ 2.72561752e+02]
#  [ 9.85453509e-02]
#  [ 1.32335588e+01]
#  [ 1.35937112e+01]
#  [ 1.32169025e+01]
#  [-2.64589355e+00]
#  [-4.00169369e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.19407084e+02]
#  [ 2.72561064e+02]
#  [ 9.86467076e-02]
#  [ 1.35096608e+01]
#  [ 1.36470760e+01]
#  [ 1.32796286e+01]
#  [-2.65280159e+00]
#  [-3.05367078e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.509660787062575
# 13.647075972206412
# --------------------------------------------
# temps entre samples:  0.1370224952697754
# state avant predict
# [[ 1.19407084e+02]
#  [ 2.72561064e+02]
#  [ 9.86467076e-02]
#  [ 1.35096608e+01]
#  [ 1.36470760e+01]
#  [ 1.32796286e+01]
#  [-2.65280159e+00]
#  [-3.05367078e-03]]
# state apres predict
# [[ 1.21226691e+02]
#  [ 2.72197571e+02]
#  [ 9.82282860e-02]
#  [ 1.35096608e+01]
#  [ 1.36470760e+01]
#  [ 1.33804360e+01]
#  [-2.67023932e+00]
#  [-1.52683539e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.21226691e+02]
#  [ 2.72197571e+02]
#  [ 9.82282860e-02]
#  [ 1.35096608e+01]
#  [ 1.36470760e+01]
#  [ 1.33804360e+01]
#  [-2.67023932e+00]
#  [-1.52683539e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.21228904e+02]
#  [ 2.72197333e+02]
#  [ 9.82619836e-02]
#  [ 1.36149466e+01]
#  [ 1.36674261e+01]
#  [ 1.34043038e+01]
#  [-2.67280300e+00]
#  [-1.16621193e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# failure in identifying corners
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.614946571782655
# 13.667426108545193
# --------------------------------------------
# temps entre samples:  0.14653873443603516
# state avant predict
# [[ 1.21228904e+02]
#  [ 2.72197333e+02]
#  [ 9.82619836e-02]
#  [ 1.36149466e+01]
#  [ 1.36674261e+01]
#  [ 1.34043038e+01]
#  [-2.67280300e+00]
#  [-1.16621193e-03]]
# state apres predict
# [[ 1.23193154e+02]
#  [ 2.71805664e+02]
#  [ 9.80910884e-02]
#  [ 1.36149466e+01]
#  [ 1.36674261e+01]
#  [ 1.34438841e+01]
#  [-2.67219816e+00]
#  [-5.83105964e-04]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.23193154e+02]
#  [ 2.71805664e+02]
#  [ 9.80910884e-02]
#  [ 1.36149466e+01]
#  [ 1.36674261e+01]
#  [ 1.34438841e+01]
#  [-2.67219816e+00]
#  [-5.83105964e-04]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.23193987e+02]
#  [ 2.71805574e+02]
#  [ 9.81037125e-02]
#  [ 1.36551524e+01]
#  [ 1.36751973e+01]
#  [ 1.34529967e+01]
#  [-2.67316385e+00]
#  [-4.45442926e-04]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.655152378827346
# 13.675197310494788
# --------------------------------------------
# temps entre samples:  0.14536142349243164
# state avant predict
# [[ 1.23193987e+02]
#  [ 2.71805574e+02]
#  [ 9.81037125e-02]
#  [ 1.36551524e+01]
#  [ 1.36751973e+01]
#  [ 1.34529967e+01]
#  [-2.67316385e+00]
#  [-4.45442926e-04]]
# state apres predict
# [[ 1.25149534e+02]
#  [ 2.71416999e+02]
#  [ 9.80389623e-02]
#  [ 1.36551524e+01]
#  [ 1.36751973e+01]
#  [ 1.34681610e+01]
#  [-2.67261336e+00]
#  [-2.22721463e-04]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.25149534e+02]
#  [ 2.71416999e+02]
#  [ 9.80389623e-02]
#  [ 1.36551524e+01]
#  [ 1.36751973e+01]
#  [ 1.34681610e+01]
#  [-2.67261336e+00]
#  [-2.22721463e-04]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.25152274e+02]
#  [ 2.71416757e+02]
#  [ 9.79895698e-02]
#  [ 1.36705091e+01]
#  [ 1.38190776e+01]
#  [ 1.34984522e+01]
#  [-2.67533227e+00]
#  [-7.68188942e-04]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.670509084399514
# 13.819077586799974
# --------------------------------------------
# temps entre samples:  0.13606619834899902
# state avant predict
# [[ 1.25152274e+02]
#  [ 2.71416757e+02]
#  [ 9.79895698e-02]
#  [ 1.36705091e+01]
#  [ 1.38190776e+01]
#  [ 1.34984522e+01]
#  [-2.67533227e+00]
#  [-7.68188942e-04]]
# state apres predict
# [[ 1.26988957e+02]
#  [ 2.71052734e+02]
#  [ 9.78850452e-02]
#  [ 1.36705091e+01]
#  [ 1.38190776e+01]
#  [ 1.35470919e+01]
#  [-2.68507741e+00]
#  [-1.65076114e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.26988957e+02]
#  [ 2.71052734e+02]
#  [ 9.78850452e-02]
#  [ 1.36705091e+01]
#  [ 1.38190776e+01]
#  [ 1.35470919e+01]
#  [-2.68507741e+00]
#  [-1.65076114e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.26987639e+02]
#  [ 2.71052847e+02]
#  [ 9.79187774e-02]
#  [ 1.36763748e+01]
#  [ 1.37331229e+01]
#  [ 1.35318515e+01]
#  [-2.68376536e+00]
#  [-1.26106867e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# failure in identifying corners
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.676374794710219
# 13.733122884787896
# --------------------------------------------
# temps entre samples:  0.14539647102355957
# state avant predict
# [[ 1.26987639e+02]
#  [ 2.71052847e+02]
#  [ 9.79187774e-02]
#  [ 1.36763748e+01]
#  [ 1.37331229e+01]
#  [ 1.35318515e+01]
#  [-2.68376536e+00]
#  [-1.26106867e-03]]
# state apres predict
# [[ 1.28955122e+02]
#  [ 2.70662637e+02]
#  [ 9.77354225e-02]
#  [ 1.36763748e+01]
#  [ 1.37331229e+01]
#  [ 1.35079077e+01]
#  [-2.67533283e+00]
#  [-6.30534334e-04]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.28955122e+02]
#  [ 2.70662637e+02]
#  [ 9.77354225e-02]
#  [ 1.36763748e+01]
#  [ 1.37331229e+01]
#  [ 1.35079077e+01]
#  [-2.67533283e+00]
#  [-6.30534334e-04]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.28949861e+02]
#  [ 2.70663148e+02]
#  [ 9.77486102e-02]
#  [ 1.35377035e+01]
#  [ 1.35593794e+01]
#  [ 1.34485210e+01]
#  [-2.66956687e+00]
#  [-4.81685334e-04]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.537703539199276
# 13.5593793792418
# --------------------------------------------
# temps entre samples:  0.13364434242248535
# state avant predict
# [[ 1.28949861e+02]
#  [ 2.70663148e+02]
#  [ 9.77486102e-02]
#  [ 1.35377035e+01]
#  [ 1.35593794e+01]
#  [ 1.34485210e+01]
#  [-2.66956687e+00]
#  [-4.81685334e-04]]
# state apres predict
# [[ 1.30747180e+02]
#  [ 2.70306375e+02]
#  [ 9.76842357e-02]
#  [ 1.35377035e+01]
#  [ 1.35593794e+01]
#  [ 1.33546188e+01]
#  [-2.64027231e+00]
#  [-2.40842667e-04]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.30747180e+02]
#  [ 2.70306375e+02]
#  [ 9.76842357e-02]
#  [ 1.35377035e+01]
#  [ 1.35593794e+01]
#  [ 1.33546188e+01]
#  [-2.64027231e+00]
#  [-2.40842667e-04]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.30742983e+02]
#  [ 2.70306809e+02]
#  [ 9.76382945e-02]
#  [ 1.33438241e+01]
#  [ 1.34930153e+01]
#  [ 1.33051782e+01]
#  [-2.63517477e+00]
#  [-7.82026321e-04]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.34382408832221
# 13.493015272751808
# --------------------------------------------
# temps entre samples:  0.14755845069885254
# state avant predict
# [[ 1.30742983e+02]
#  [ 2.70306809e+02]
#  [ 9.76382945e-02]
#  [ 1.33438241e+01]
#  [ 1.34930153e+01]
#  [ 1.33051782e+01]
#  [-2.63517477e+00]
#  [-7.82026321e-04]]
# state apres predict
# [[ 1.32706275e+02]
#  [ 2.69917967e+02]
#  [ 9.75228999e-02]
#  [ 1.33438241e+01]
#  [ 1.34930153e+01]
#  [ 1.32267922e+01]
#  [-2.61198252e+00]
#  [-1.65767983e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.32706275e+02]
#  [ 2.69917967e+02]
#  [ 9.75228999e-02]
#  [ 1.33438241e+01]
#  [ 1.34930153e+01]
#  [ 1.32267922e+01]
#  [-2.61198252e+00]
#  [-1.65767983e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.32702218e+02]
#  [ 2.69918349e+02]
#  [ 9.75576446e-02]
#  [ 1.32697687e+01]
#  [ 1.33267547e+01]
#  [ 1.31810979e+01]
#  [-2.60767786e+00]
#  [-1.26635470e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.269768728998317
# 13.326754690540682
# --------------------------------------------
# temps entre samples:  0.13450860977172852
# state avant predict
# [[ 1.32702218e+02]
#  [ 2.69918349e+02]
#  [ 9.75576446e-02]
#  [ 1.32697687e+01]
#  [ 1.33267547e+01]
#  [ 1.31810979e+01]
#  [-2.60767786e+00]
#  [-1.26635470e-03]]
# state apres predict
# [[ 1.34475189e+02]
#  [ 2.69567594e+02]
#  [ 9.73873090e-02]
#  [ 1.32697687e+01]
#  [ 1.33267547e+01]
#  [ 1.31086634e+01]
#  [-2.58646839e+00]
#  [-6.33177350e-04]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.34475189e+02]
#  [ 2.69567594e+02]
#  [ 9.73873090e-02]
#  [ 1.32697687e+01]
#  [ 1.33267547e+01]
#  [ 1.31086634e+01]
#  [-2.58646839e+00]
#  [-6.33177350e-04]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.34480547e+02]
#  [ 2.69566995e+02]
#  [ 9.75530806e-02]
#  [ 1.36642173e+01]
#  [ 1.32632488e+01]
#  [ 1.31714819e+01]
#  [-2.59349707e+00]
#  [ 1.31041218e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# failure in identifying corners
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.664217347215098
# 13.263248799274072
# --------------------------------------------
# temps entre samples:  0.14686822891235352
# state avant predict
# [[ 1.34480547e+02]
#  [ 2.69566995e+02]
#  [ 9.75530806e-02]
#  [ 1.36642173e+01]
#  [ 1.32632488e+01]
#  [ 1.31714819e+01]
#  [-2.59349707e+00]
#  [ 1.31041218e-03]]
# state apres predict
# [[ 1.36415019e+02]
#  [ 2.69186092e+02]
#  [ 9.77455386e-02]
#  [ 1.36642173e+01]
#  [ 1.32632488e+01]
#  [ 1.32717935e+01]
#  [-2.61853030e+00]
#  [ 4.45520609e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.36415019e+02]
#  [ 2.69186092e+02]
#  [ 9.77455386e-02]
#  [ 1.36642173e+01]
#  [ 1.32632488e+01]
#  [ 1.32717935e+01]
#  [-2.61853030e+00]
#  [ 4.45520609e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.36417151e+02]
#  [ 2.69185902e+02]
#  [ 9.77053064e-02]
#  [ 1.36739716e+01]
#  [ 1.33799035e+01]
#  [ 1.32958400e+01]
#  [-2.62068363e+00]
#  [ 4.00151347e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.673971563068994
# 13.379903456742408
# --------------------------------------------
# temps entre samples:  0.13391566276550293
# state avant predict
# [[ 1.36417151e+02]
#  [ 2.69185902e+02]
#  [ 9.77053064e-02]
#  [ 1.36739716e+01]
#  [ 1.33799035e+01]
#  [ 1.32958400e+01]
#  [-2.62068363e+00]
#  [ 4.00151347e-03]]
# state apres predict
# [[ 1.38197673e+02]
#  [ 2.68834951e+02]
#  [ 9.82411717e-02]
#  [ 1.36739716e+01]
#  [ 1.33799035e+01]
#  [ 1.33334954e+01]
#  [-2.63490188e+00]
#  [ 3.26742340e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.38197673e+02]
#  [ 2.68834951e+02]
#  [ 9.82411717e-02]
#  [ 1.36739716e+01]
#  [ 1.33799035e+01]
#  [ 1.33334954e+01]
#  [-2.63490188e+00]
#  [ 3.26742340e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.38196179e+02]
#  [ 2.68835126e+02]
#  [ 9.81755907e-02]
#  [ 1.35367856e+01]
#  [ 1.34244616e+01]
#  [ 1.33159239e+01]
#  [-2.63282446e+00]
#  [ 2.49608937e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.53678559255601
# 13.42446157094711
# --------------------------------------------
# temps entre samples:  0.1470022201538086
# state avant predict
# [[ 1.38196179e+02]
#  [ 2.68835126e+02]
#  [ 9.81755907e-02]
#  [ 1.35367856e+01]
#  [ 1.34244616e+01]
#  [ 1.33159239e+01]
#  [-2.63282446e+00]
#  [ 2.49608937e-03]]
# state apres predict
# [[ 1.40153649e+02]
#  [ 2.68448095e+02]
#  [ 9.85425214e-02]
#  [ 1.35367856e+01]
#  [ 1.34244616e+01]
#  [ 1.32859860e+01]
#  [-2.63843839e+00]
#  [ 1.24804468e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.40153649e+02]
#  [ 2.68448095e+02]
#  [ 9.85425214e-02]
#  [ 1.35367856e+01]
#  [ 1.34244616e+01]
#  [ 1.32859860e+01]
#  [-2.63843839e+00]
#  [ 1.24804468e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.40157802e+02]
#  [ 2.68447700e+02]
#  [ 9.85164102e-02]
#  [ 1.36252970e+01]
#  [ 1.35823930e+01]
#  [ 1.33328384e+01]
#  [-2.64292338e+00]
#  [ 9.53421300e-04]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.62529696403511
# 13.582393005533618
# --------------------------------------------
# temps entre samples:  0.1360642910003662
# state avant predict
# [[ 1.40157802e+02]
#  [ 2.68447700e+02]
#  [ 9.85164102e-02]
#  [ 1.36252970e+01]
#  [ 1.35823930e+01]
#  [ 1.33328384e+01]
#  [-2.64292338e+00]
#  [ 9.53421300e-04]]
# state apres predict
# [[ 1.41971925e+02]
#  [ 2.68088093e+02]
#  [ 9.86461368e-02]
#  [ 1.36252970e+01]
#  [ 1.35823930e+01]
#  [ 1.34060640e+01]
#  [-2.67173872e+00]
#  [ 4.76710650e-04]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.41971925e+02]
#  [ 2.68088093e+02]
#  [ 9.86461368e-02]
#  [ 1.36252970e+01]
#  [ 1.35823930e+01]
#  [ 1.34060640e+01]
#  [-2.67173872e+00]
#  [ 4.76710650e-04]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.41973465e+02]
#  [ 2.68087992e+02]
#  [ 9.85338264e-02]
#  [ 1.35181936e+01]
#  [ 1.37836292e+01]
#  [ 1.34240139e+01]
#  [-2.67290724e+00]
#  [-8.31903222e-04]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.518193550114237
# 13.783629195088553
# --------------------------------------------
# temps entre samples:  0.13485050201416016
# state avant predict
# [[ 1.41973465e+02]
#  [ 2.68087992e+02]
#  [ 9.85338264e-02]
#  [ 1.35181936e+01]
#  [ 1.37836292e+01]
#  [ 1.34240139e+01]
#  [-2.67290724e+00]
#  [-8.31903222e-04]]
# state apres predict
# [[ 1.43783700e+02]
#  [ 2.67727549e+02]
#  [ 9.84216438e-02]
#  [ 1.35181936e+01]
#  [ 1.37836292e+01]
#  [ 1.34523760e+01]
#  [-2.68145324e+00]
#  [-2.94928494e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.43783700e+02]
#  [ 2.67727549e+02]
#  [ 9.84216438e-02]
#  [ 1.35181936e+01]
#  [ 1.37836292e+01]
#  [ 1.34523760e+01]
#  [-2.68145324e+00]
#  [-2.94928494e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.43777503e+02]
#  [ 2.67728156e+02]
#  [ 9.84299205e-02]
#  [ 1.33363719e+01]
#  [ 1.35786711e+01]
#  [ 1.33788616e+01]
#  [-2.67423021e+00]
#  [-2.85109209e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# failure in identifying corners
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.33637193687264
# 13.578671080862055
# --------------------------------------------
# temps entre samples:  0.14872074127197266
# state avant predict
# [[ 1.43777503e+02]
#  [ 2.67728156e+02]
#  [ 9.84299205e-02]
#  [ 1.33363719e+01]
#  [ 1.35786711e+01]
#  [ 1.33788616e+01]
#  [-2.67423021e+00]
#  [-2.85109209e-03]]
# state apres predict
# [[ 1.45767218e+02]
#  [ 2.67330443e+02]
#  [ 9.80059040e-02]
#  [ 1.33363719e+01]
#  [ 1.35786711e+01]
#  [ 1.32622108e+01]
#  [-2.64069607e+00]
#  [-2.69221271e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.45767218e+02]
#  [ 2.67330443e+02]
#  [ 9.80059040e-02]
#  [ 1.33363719e+01]
#  [ 1.35786711e+01]
#  [ 1.32622108e+01]
#  [-2.64069607e+00]
#  [-2.69221271e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.45771867e+02]
#  [ 2.67329958e+02]
#  [ 9.80624689e-02]
#  [ 1.35487458e+01]
#  [ 1.36412958e+01]
#  [ 1.33144496e+01]
#  [-2.64613130e+00]
#  [-2.05666750e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.548745759373643
# 13.641295796932594
# --------------------------------------------
# temps entre samples:  0.13635706901550293
# state avant predict
# [[ 1.45771867e+02]
#  [ 2.67329958e+02]
#  [ 9.80624689e-02]
#  [ 1.35487458e+01]
#  [ 1.36412958e+01]
#  [ 1.33144496e+01]
#  [-2.64613130e+00]
#  [-2.05666750e-03]]
# state apres predict
# [[ 1.47587386e+02]
#  [ 2.66969139e+02]
#  [ 9.77820278e-02]
#  [ 1.35487458e+01]
#  [ 1.36412958e+01]
#  [ 1.33991829e+01]
#  [-2.65778209e+00]
#  [-1.02833375e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.47587386e+02]
#  [ 2.66969139e+02]
#  [ 9.77820278e-02]
#  [ 1.35487458e+01]
#  [ 1.36412958e+01]
#  [ 1.33991829e+01]
#  [-2.65778209e+00]
#  [-1.02833375e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.47584493e+02]
#  [ 2.66969416e+02]
#  [ 9.78029241e-02]
#  [ 1.34889536e+01]
#  [ 1.35243046e+01]
#  [ 1.33655715e+01]
#  [-2.65458821e+00]
#  [-7.85577082e-04]]
# angle from camera: None
# <class 'numpy.float64'>
# failure in identifying corners
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.488953591813313
# 13.524304560500752
# --------------------------------------------
# temps entre samples:  0.1466507911682129
# state avant predict
# [[ 1.47584493e+02]
#  [ 2.66969416e+02]
#  [ 9.78029241e-02]
#  [ 1.34889536e+01]
#  [ 1.35243046e+01]
#  [ 1.33655715e+01]
#  [-2.65458821e+00]
#  [-7.85577082e-04]]
# state apres predict
# [[ 1.49544565e+02]
#  [ 2.66580118e+02]
#  [ 9.76877186e-02]
#  [ 1.34889536e+01]
#  [ 1.35243046e+01]
#  [ 1.33130917e+01]
#  [-2.63355782e+00]
#  [-3.92788541e-04]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.49544565e+02]
#  [ 2.66580118e+02]
#  [ 9.76877186e-02]
#  [ 1.34889536e+01]
#  [ 1.35243046e+01]
#  [ 1.33130917e+01]
#  [-2.63355782e+00]
#  [-3.92788541e-04]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.49548190e+02]
#  [ 2.66579806e+02]
#  [ 9.75896360e-02]
#  [ 1.34661150e+01]
#  [ 1.37614414e+01]
#  [ 1.33538713e+01]
#  [-2.63706660e+00]
#  [-1.49614150e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  0
# elements:  0
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.466115016066295
# 13.761441383439616
# --------------------------------------------
# temps entre samples:  0.13397598266601562
# state avant predict
# [[ 1.49548190e+02]
#  [ 2.66579806e+02]
#  [ 9.75896360e-02]
#  [ 1.34661150e+01]
#  [ 1.37614414e+01]
#  [ 1.33538713e+01]
#  [-2.63706660e+00]
#  [-1.49614150e-03]]
# state apres predict
# [[ 1.51337288e+02]
#  [ 2.66226502e+02]
#  [ 9.73891890e-02]
#  [ 1.34661150e+01]
#  [ 1.37614414e+01]
#  [ 1.34195543e+01]
#  [-2.64869808e+00]
#  [-3.28140408e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.51337288e+02]
#  [ 2.66226502e+02]
#  [ 9.73891890e-02]
#  [ 1.34661150e+01]
#  [ 1.37614414e+01]
#  [ 1.34195543e+01]
#  [-2.64869808e+00]
#  [-3.28140408e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.51338614e+02]
#  [ 2.66226388e+02]
#  [ 9.73533118e-02]
#  [ 1.34573915e+01]
#  [ 1.38520196e+01]
#  [ 1.34351317e+01]
#  [-2.65002738e+00]
#  [-3.70284741e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  1
# elements:  1
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.457391456385574
# 13.852019589818097
# --------------------------------------------
# temps entre samples:  0.13765215873718262
# state avant predict
# [[ 1.51338614e+02]
#  [ 2.66226388e+02]
#  [ 9.73533118e-02]
#  [ 1.34573915e+01]
#  [ 1.38520196e+01]
#  [ 1.34351317e+01]
#  [-2.65002738e+00]
#  [-3.70284741e-03]]
# state apres predict
# [[ 1.53187989e+02]
#  [ 2.65861606e+02]
#  [ 9.68436069e-02]
#  [ 1.34573915e+01]
#  [ 1.38520196e+01]
#  [ 1.34608388e+01]
#  [-2.65026827e+00]
#  [-4.38475704e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.53187989e+02]
#  [ 2.65861606e+02]
#  [ 9.68436069e-02]
#  [ 1.34573915e+01]
#  [ 1.38520196e+01]
#  [ 1.34608388e+01]
#  [-2.65026827e+00]
#  [-4.38475704e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.53193049e+02]
#  [ 2.65861069e+02]
#  [ 9.69316887e-02]
#  [ 1.37358829e+01]
#  [ 1.38866174e+01]
#  [ 1.35203057e+01]
#  [-2.65653771e+00]
#  [-3.34965631e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  1
# elements:  1
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.735882851960378
# 13.886617386014674
# --------------------------------------------
# temps entre samples:  0.14911818504333496
# state avant predict
# [[ 1.53193049e+02]
#  [ 2.65861069e+02]
#  [ 9.69316887e-02]
#  [ 1.37358829e+01]
#  [ 1.38866174e+01]
#  [ 1.35203057e+01]
#  [-2.65653771e+00]
#  [-3.34965631e-03]]
# state apres predict
# [[ 1.55209172e+02]
#  [ 2.65464931e+02]
#  [ 9.64321940e-02]
#  [ 1.37358829e+01]
#  [ 1.38866174e+01]
#  [ 1.36168534e+01]
#  [-2.66911581e+00]
#  [-1.67482816e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.55209172e+02]
#  [ 2.65464931e+02]
#  [ 9.64321940e-02]
#  [ 1.37358829e+01]
#  [ 1.38866174e+01]
#  [ 1.36168534e+01]
#  [-2.66911581e+00]
#  [-1.67482816e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.55206407e+02]
#  [ 2.65465138e+02]
#  [ 9.65745675e-02]
#  [ 1.38422571e+01]
#  [ 1.36180091e+01]
#  [ 1.35859457e+01]
#  [-2.66682825e+00]
#  [-8.33771080e-05]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  1
# elements:  1
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.842257099495562
# 13.618009069355972
# --------------------------------------------
# temps entre samples:  0.13489723205566406
# state avant predict
# [[ 1.55206407e+02]
#  [ 2.65465138e+02]
#  [ 9.65745675e-02]
#  [ 1.38422571e+01]
#  [ 1.36180091e+01]
#  [ 1.35859457e+01]
#  [-2.66682825e+00]
#  [-8.33771080e-05]]
# state apres predict
# [[ 1.57039114e+02]
#  [ 2.65105390e+02]
#  [ 9.65633202e-02]
#  [ 1.38422571e+01]
#  [ 1.36180091e+01]
#  [ 1.35382976e+01]
#  [-2.64372445e+00]
#  [ 2.49164478e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 1.57039114e+02]
#  [ 2.65105390e+02]
#  [ 9.65633202e-02]
#  [ 1.38422571e+01]
#  [ 1.36180091e+01]
#  [ 1.35382976e+01]
#  [-2.64372445e+00]
#  [ 2.49164478e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 1.57033516e+02]
#  [ 2.65105958e+02]
#  [ 9.65129132e-02]
#  [ 1.36010649e+01]
#  [ 1.35154098e+01]
#  [ 1.34729719e+01]
#  [-2.63711870e+00]
#  [ 1.90344724e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.601064947656354
# 13.515409822053243
# --------------------------------------------
# temps entre samples:  0.14775705337524414
# state avant predict
# [[ 1.57033516e+02]
#  [ 2.65105958e+02]
#  [ 9.65129132e-02]
#  [ 1.36010649e+01]
#  [ 1.35154098e+01]
#  [ 1.34729719e+01]
#  [-2.63711870e+00]
#  [ 1.90344724e-03]]
# state apres predict
# [[ 1.59024242e+02]
#  [ 2.64716305e+02]
#  [ 9.67941609e-02]
#  [ 1.36010649e+01]
#  [ 1.35154098e+01]
#  [ 1.33690451e+01]
#  [-2.60896981e+00]
#  [ 9.51723618e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.05045659667881854
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.521785732759176
# 13.537790721916899
# --------------------------------------------
# temps entre samples:  0.1346454620361328
# state avant predict
# [[ 1.50370647e+02]
#  [ 2.77317431e+02]
#  [ 3.21015673e-02]
#  [ 1.35217857e+01]
#  [ 1.35377907e+01]
#  [ 1.34947128e+01]
#  [-1.13102489e+00]
#  [ 5.20571566e-04]]
# state apres predict
# [[ 1.52187649e+02]
#  [ 2.77165144e+02]
#  [ 3.21716599e-02]
#  [ 1.35217857e+01]
#  [ 1.35377907e+01]
#  [ 1.35088773e+01]
#  [-8.68356450e-01]
#  [-1.77833213e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.04820056002480644
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.42452356678716
# 13.493114224033825
# --------------------------------------------
# temps entre samples:  0.14592409133911133
# state avant predict
# [[ 1.51203315e+02]
#  [ 2.77709335e+02]
#  [ 3.11770671e-02]
#  [ 1.34245236e+01]
#  [ 1.34931142e+01]
#  [ 1.34730855e+01]
#  [-3.09530520e-01]
#  [-5.09087711e-04]]
# state apres predict
# [[ 1.53169363e+02]
#  [ 2.77664167e+02]
#  [ 3.11027789e-02]
#  [ 1.34245236e+01]
#  [ 1.34931142e+01]
#  [ 1.34391984e+01]
#  [-8.38941112e-01]
#  [-7.62118414e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.026162932639111305
# <class 'numpy.float64'>
# failure in identifying corners
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.342588793561308
# 13.456092973435734
# --------------------------------------------
# temps entre samples:  0.1368718147277832
# state avant predict
# [[ 1.52614389e+02]
#  [ 2.77226041e+02]
#  [ 3.53452973e-02]
#  [ 1.33425888e+01]
#  [ 1.34560930e+01]
#  [ 1.33773717e+01]
#  [-1.19444019e+00]
#  [-1.07941816e-03]]
# state apres predict
# [[ 1.54445375e+02]
#  [ 2.77062556e+02]
#  [ 3.51975554e-02]
#  [ 1.33425888e+01]
#  [ 1.34560930e+01]
#  [ 1.33742357e+01]
#  [-9.46812965e-01]
#  [-1.26115755e-03]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.040633403069546624
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.351149633495963
# 13.430724031654975
# --------------------------------------------
# temps entre samples:  0.13751626014709473
# state avant predict
# [[ 1.54031351e+02]
#  [ 2.77591500e+02]
#  [ 3.05242495e-02]
#  [ 1.33511496e+01]
#  [ 1.34307240e+01]
#  [ 1.33707093e+01]
#  [-5.61870553e-01]
#  [-1.01046855e-03]]
# state apres predict
# [[ 1.55870041e+02]
#  [ 2.77514234e+02]
#  [ 3.03852936e-02]
#  [ 1.33511496e+01]
#  [ 1.34307240e+01]
#  [ 1.33722242e+01]
#  [-8.17242716e-01]
#  [-8.84159980e-04]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.016660312729515864
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.445829164494167
# 13.570869921092237
# --------------------------------------------
# temps entre samples:  0.14679598808288574
# state avant predict
# [[ 1.55778977e+02]
#  [ 2.77288335e+02]
#  [ 2.39826019e-02]
#  [ 1.34458292e+01]
#  [ 1.35708699e+01]
#  [ 1.34442811e+01]
#  [-9.67381465e-01]
#  [-1.22591437e-03]]
# state apres predict
# [[ 1.57752543e+02]
#  [ 2.77146328e+02]
#  [ 2.38026425e-02]
#  [ 1.34458292e+01]
#  [ 1.35708699e+01]
#  [ 1.34966962e+01]
#  [-6.47806520e-01]
#  [-1.38934174e-03]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# angle from camera: 0.037742164684367495
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 13.536931502434664
# 13.69376763699318
# --------------------------------------------
# temps entre samples:  0.1360785961151123
# state avant predict
# [[ 1.58046464e+02]
#  [ 2.77520917e+02]
#  [ 2.78330847e-02]
#  [ 1.35369315e+01]
#  [ 1.36937676e+01]
#  [ 1.35846412e+01]
#  [-3.79203726e-01]
#  [-1.62966520e-03]]
# state apres predict
# [[ 1.59895043e+02]
#  [ 2.77469315e+02]
#  [ 2.76113222e-02]
#  [ 1.35369315e+01]
#  [ 1.36937676e+01]
#  [ 1.35995300e+01]
# ...
#  [ 1.33917032e+01]
#  [-1.60659571e+00]
#  [ 1.91518039e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.74312900e+02]
#  [ 2.54323619e+02]
#  [ 5.97684956e-02]
#  [ 1.34893997e+01]
#  [ 1.37053851e+01]
#  [ 1.34427121e+01]
#  [-1.60887972e+00]
#  [ 2.66989876e-04]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  3
# elements:  3
# thymio indetectable
# Vitesses droite / gauche -------------------
# 13.489399682867885
# 13.705385138426744
# --------------------------------------------
# temps entre samples:  0.13868379592895508
# state avant predict
# [[ 5.74312900e+02]
#  [ 2.54323619e+02]
#  [ 5.97684956e-02]
#  [ 1.34893997e+01]
#  [ 1.37053851e+01]
#  [ 1.34427121e+01]
#  [-1.60887972e+00]
#  [ 2.66989876e-04]]
# state apres predict
# [[ 5.76177186e+02]
#  [ 2.54100493e+02]
#  [ 5.98055228e-02]
#  [ 1.34893997e+01]
#  [ 1.37053851e+01]
#  [ 1.35245682e+01]
#  [-1.62345645e+00]
#  [-2.39983840e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.76177186e+02]
#  [ 2.54100493e+02]
#  [ 5.98055228e-02]
#  [ 1.34893997e+01]
#  [ 1.37053851e+01]
#  [ 1.35245682e+01]
#  [-1.62345645e+00]
#  [-2.39983840e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.76176548e+02]
#  [ 2.54100485e+02]
#  [ 5.99055808e-02]
#  [ 1.36071972e+01]
#  [ 1.35487845e+01]
#  [ 1.35171395e+01]
#  [-1.62353456e+00]
#  [-1.23527452e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.607197157122041
# 13.548784510634919
# --------------------------------------------
# temps entre samples:  0.15076494216918945
# state avant predict
# [[ 5.76176548e+02]
#  [ 2.54100485e+02]
#  [ 5.99055808e-02]
#  [ 1.36071972e+01]
#  [ 1.35487845e+01]
#  [ 1.35171395e+01]
#  [-1.62353456e+00]
#  [-1.23527452e-03]]
# state apres predict
# [[ 5.78214458e+02]
#  [ 2.53855713e+02]
#  [ 5.97193447e-02]
#  [ 1.36071972e+01]
#  [ 1.35487845e+01]
#  [ 1.35049367e+01]
#  [-1.62484936e+00]
#  [ 6.49029405e-04]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.78214458e+02]
#  [ 2.53855713e+02]
#  [ 5.97193447e-02]
#  [ 1.36071972e+01]
#  [ 1.35487845e+01]
#  [ 1.35049367e+01]
#  [-1.62484936e+00]
#  [ 6.49029405e-04]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.78216632e+02]
#  [ 2.53855589e+02]
#  [ 5.97054933e-02]
#  [ 1.36521918e+01]
#  [ 1.36298801e+01]
#  [ 1.35289787e+01]
#  [-1.62622294e+00]
#  [ 4.95814346e-04]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.652191788498238
# 13.62988014291299
# --------------------------------------------
# temps entre samples:  0.14877820014953613
# state avant predict
# [[ 5.78216632e+02]
#  [ 2.53855589e+02]
#  [ 5.97054933e-02]
#  [ 1.36521918e+01]
#  [ 1.36298801e+01]
#  [ 1.35289787e+01]
#  [-1.62622294e+00]
#  [ 4.95814346e-04]]
# state apres predict
# [[ 5.80229449e+02]
#  [ 2.53613643e+02]
#  [ 5.97792597e-02]
#  [ 1.36521918e+01]
#  [ 1.36298801e+01]
#  [ 1.35681318e+01]
#  [-1.62695455e+00]
#  [ 2.47907173e-04]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.80229449e+02]
#  [ 2.53613643e+02]
#  [ 5.97792597e-02]
#  [ 1.36521918e+01]
#  [ 1.36298801e+01]
#  [ 1.35681318e+01]
#  [-1.62695455e+00]
#  [ 2.47907173e-04]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.80227835e+02]
#  [ 2.53613767e+02]
#  [ 5.97192762e-02]
#  [ 1.35284665e+01]
#  [ 1.36608559e+01]
#  [ 1.35504683e+01]
#  [-1.62558886e+00]
#  [-4.08654648e-04]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.528466458937697
# 13.66085591810405
# --------------------------------------------
# temps entre samples:  0.13640785217285156
# state avant predict
# [[ 5.80227835e+02]
#  [ 2.53613767e+02]
#  [ 5.97192762e-02]
#  [ 1.35284665e+01]
#  [ 1.36608559e+01]
#  [ 1.35504683e+01]
#  [-1.62558886e+00]
#  [-4.08654648e-04]]
# state apres predict
# [[ 5.82076226e+02]
#  [ 2.53392023e+02]
#  [ 5.96635325e-02]
#  [ 1.35284665e+01]
#  [ 1.36608559e+01]
#  [ 1.35219714e+01]
#  [-1.62179689e+00]
#  [-1.47099399e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.82076226e+02]
#  [ 2.53392023e+02]
#  [ 5.96635325e-02]
#  [ 1.35284665e+01]
#  [ 1.36608559e+01]
#  [ 1.35219714e+01]
#  [-1.62179689e+00]
#  [-1.47099399e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.82075639e+02]
#  [ 2.53392069e+02]
#  [ 5.96417144e-02]
#  [ 1.34812076e+01]
#  [ 1.36726876e+01]
#  [ 1.35152245e+01]
#  [-1.62127431e+00]
#  [-1.72177829e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# failure in identifying corners
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.481207588314852
# 13.672687611399159
# --------------------------------------------
# temps entre samples:  0.14785385131835938
# state avant predict
# [[ 5.82075639e+02]
#  [ 2.53392069e+02]
#  [ 5.96417144e-02]
#  [ 1.34812076e+01]
#  [ 1.36726876e+01]
#  [ 1.35152245e+01]
#  [-1.62127431e+00]
#  [-1.72177829e-03]]
# state apres predict
# [[ 5.84073917e+02]
#  [ 2.53152357e+02]
#  [ 5.93871429e-02]
#  [ 1.34812076e+01]
#  [ 1.36726876e+01]
#  [ 1.35045408e+01]
#  [-1.61758511e+00]
#  [-2.12755581e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.84073917e+02]
#  [ 2.53152357e+02]
#  [ 5.93871429e-02]
#  [ 1.34812076e+01]
#  [ 1.36726876e+01]
#  [ 1.35045408e+01]
#  [-1.61758511e+00]
#  [-2.12755581e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.84080910e+02]
#  [ 2.53151867e+02]
#  [ 5.95394929e-02]
#  [ 1.38858916e+01]
#  [ 1.36772069e+01]
#  [ 1.35825071e+01]
#  [-1.62300828e+00]
#  [-4.29230262e-04]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.885891554311787
# 13.677206916093425
# --------------------------------------------
# temps entre samples:  0.13466978073120117
# state avant predict
# [[ 5.84080910e+02]
#  [ 2.53151867e+02]
#  [ 5.95394929e-02]
#  [ 1.38858916e+01]
#  [ 1.36772069e+01]
#  [ 1.35825071e+01]
#  [-1.62300828e+00]
#  [-4.29230262e-04]]
# state apres predict
# [[ 5.85910064e+02]
#  [ 2.52933297e+02]
#  [ 5.94816885e-02]
#  [ 1.38858916e+01]
#  [ 1.36772069e+01]
#  [ 1.37083029e+01]
#  [-1.63915422e+00]
#  [ 2.31871820e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.85910064e+02]
#  [ 2.52933297e+02]
#  [ 5.94816885e-02]
#  [ 1.38858916e+01]
#  [ 1.36772069e+01]
#  [ 1.37083029e+01]
#  [-1.63915422e+00]
#  [ 2.31871820e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.85905710e+02]
#  [ 2.52933555e+02]
#  [ 5.94860306e-02]
#  [ 1.37586436e+01]
#  [ 1.35380214e+01]
#  [ 1.36575074e+01]
#  [-1.63615027e+00]
#  [ 2.36938196e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.758643575750558
# 13.538021387446143
# --------------------------------------------
# temps entre samples:  0.1466846466064453
# state avant predict
# [[ 5.85905710e+02]
#  [ 2.52933555e+02]
#  [ 5.94860306e-02]
#  [ 1.37586436e+01]
#  [ 1.35380214e+01]
#  [ 1.36575074e+01]
#  [-1.63615027e+00]
#  [ 2.36938196e-03]]
# state apres predict
# [[ 5.87909057e+02]
#  [ 2.52693557e+02]
#  [ 5.98335826e-02]
#  [ 1.37586436e+01]
#  [ 1.35380214e+01]
#  [ 1.35759243e+01]
#  [-1.62185547e+00]
#  [ 2.45135765e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.87909057e+02]
#  [ 2.52693557e+02]
#  [ 5.98335826e-02]
#  [ 1.37586436e+01]
#  [ 1.35380214e+01]
#  [ 1.35759243e+01]
#  [-1.62185547e+00]
#  [ 2.45135765e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.87909721e+02]
#  [ 2.52693541e+02]
#  [ 5.97822157e-02]
#  [ 1.37100392e+01]
#  [ 1.36257690e+01]
#  [ 1.35834022e+01]
#  [-1.62204181e+00]
#  [ 1.87267061e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.710039172939886
# 13.625768995679978
# --------------------------------------------
# temps entre samples:  0.1394505500793457
# state avant predict
# [[ 5.87909721e+02]
#  [ 2.52693541e+02]
#  [ 5.97822157e-02]
#  [ 1.37100392e+01]
#  [ 1.36257690e+01]
#  [ 1.35834022e+01]
#  [-1.62204181e+00]
#  [ 1.87267061e-03]]
# state apres predict
# [[ 5.89803934e+02]
#  [ 2.52467347e+02]
#  [ 6.00433606e-02]
#  [ 1.37100392e+01]
#  [ 1.36257690e+01]
#  [ 1.35946686e+01]
#  [-1.63224888e+00]
#  [ 9.36335303e-04]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.89803934e+02]
#  [ 2.52467347e+02]
#  [ 6.00433606e-02]
#  [ 1.37100392e+01]
#  [ 1.36257690e+01]
#  [ 1.35946686e+01]
#  [-1.63224888e+00]
#  [ 9.36335303e-04]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.89799502e+02]
#  [ 2.52467667e+02]
#  [ 5.99198300e-02]
#  [ 1.34096504e+01]
#  [ 1.36592856e+01]
#  [ 1.35438308e+01]
#  [-1.62854818e+00]
#  [-4.80781231e-04]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.409650444199148
# 13.659285599593794
# --------------------------------------------
# temps entre samples:  0.1385660171508789
# state avant predict
# [[ 5.89799502e+02]
#  [ 2.52467667e+02]
#  [ 5.99198300e-02]
#  [ 1.34096504e+01]
#  [ 1.36592856e+01]
#  [ 1.35438308e+01]
#  [-1.62854818e+00]
#  [-4.80781231e-04]]
# state apres predict
# [[ 5.91676217e+02]
#  [ 2.52242006e+02]
#  [ 5.98532101e-02]
#  [ 1.34096504e+01]
#  [ 1.36592856e+01]
#  [ 1.34616134e+01]
#  [-1.62002541e+00]
#  [-2.77372395e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.91676217e+02]
#  [ 2.52242006e+02]
#  [ 5.98532101e-02]
#  [ 1.34096504e+01]
#  [ 1.36592856e+01]
#  [ 1.34616134e+01]
#  [-1.62002541e+00]
#  [-2.77372395e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.91676857e+02]
#  [ 2.52241965e+02]
#  [ 5.98581031e-02]
#  [ 1.34358239e+01]
#  [ 1.36720878e+01]
#  [ 1.34690422e+01]
#  [-1.62049669e+00]
#  [-2.71697542e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.435823909092536
# 13.672087803101403
# --------------------------------------------
# temps entre samples:  0.1364610195159912
# state avant predict
# [[ 5.91676857e+02]
#  [ 2.52241965e+02]
#  [ 5.98581031e-02]
#  [ 1.34358239e+01]
#  [ 1.36720878e+01]
#  [ 1.34690422e+01]
#  [-1.62049669e+00]
#  [-2.71697542e-03]]
# state apres predict
# [[ 5.93514856e+02]
#  [ 2.52020830e+02]
#  [ 5.94873419e-02]
#  [ 1.34358239e+01]
#  [ 1.36720878e+01]
#  [ 1.34811465e+01]
#  [-1.62069074e+00]
#  [-2.62515438e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.93514856e+02]
#  [ 2.52020830e+02]
#  [ 5.94873419e-02]
#  [ 1.34358239e+01]
#  [ 1.36720878e+01]
#  [ 1.34811465e+01]
#  [-1.62069074e+00]
#  [-2.62515438e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.93515095e+02]
#  [ 2.52020769e+02]
#  [ 5.95909216e-02]
#  [ 1.35867330e+01]
#  [ 1.35360661e+01]
#  [ 1.34839521e+01]
#  [-1.62140345e+00]
#  [-1.40740062e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.586733032513433
# 13.536066060275441
# --------------------------------------------
# temps entre samples:  0.15032386779785156
# state avant predict
# [[ 5.93515095e+02]
#  [ 2.52020769e+02]
#  [ 5.95909216e-02]
#  [ 1.35867330e+01]
#  [ 1.35360661e+01]
#  [ 1.34839521e+01]
#  [-1.62140345e+00]
#  [-1.40740062e-03]]
# state apres predict
# [[ 5.95542055e+02]
#  [ 2.51777033e+02]
#  [ 5.93793556e-02]
#  [ 1.35867330e+01]
#  [ 1.35360661e+01]
#  [ 1.34891988e+01]
#  [-1.61435993e+00]
#  [ 5.62966358e-04]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.95542055e+02]
#  [ 2.51777033e+02]
#  [ 5.93793556e-02]
#  [ 1.35867330e+01]
#  [ 1.35360661e+01]
#  [ 1.34891988e+01]
#  [-1.61435993e+00]
#  [ 5.62966358e-04]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.95542151e+02]
#  [ 2.51777009e+02]
#  [ 5.94211754e-02]
#  [ 1.36443752e+01]
#  [ 1.34841104e+01]
#  [ 1.34902707e+01]
#  [-1.61462919e+00]
#  [ 1.02810690e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.644375188447762
# 13.484110377724921
# --------------------------------------------
# temps entre samples:  0.1553027629852295
# state avant predict
# [[ 5.95542151e+02]
#  [ 2.51777009e+02]
#  [ 5.94211754e-02]
#  [ 1.36443752e+01]
#  [ 1.34841104e+01]
#  [ 1.34902707e+01]
#  [-1.61462919e+00]
#  [ 1.02810690e-03]]
# state apres predict
# [[ 5.97637228e+02]
#  [ 2.51526252e+02]
#  [ 5.95808433e-02]
#  [ 1.36443752e+01]
#  [ 1.34841104e+01]
#  [ 1.34924375e+01]
#  [-1.61010974e+00]
#  [ 1.78072012e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.97637228e+02]
#  [ 2.51526252e+02]
#  [ 5.95808433e-02]
#  [ 1.36443752e+01]
#  [ 1.34841104e+01]
#  [ 1.34924375e+01]
#  [-1.61010974e+00]
#  [ 1.78072012e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.97642298e+02]
#  [ 2.51525942e+02]
#  [ 5.95974840e-02]
#  [ 1.38073043e+01]
#  [ 1.36051768e+01]
#  [ 1.35465752e+01]
#  [-1.61341336e+00]
#  [ 1.95838800e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# trop grande différence d'angle detectée
# Vitesses droite / gauche -------------------
# 13.80730428226483
# 13.605176822334299
# --------------------------------------------
# temps entre samples:  0.1361250877380371
# state avant predict
# [[ 5.97642298e+02]
#  [ 2.51525942e+02]
#  [ 5.95974840e-02]
#  [ 1.38073043e+01]
#  [ 1.36051768e+01]
#  [ 1.35465752e+01]
#  [-1.61341336e+00]
#  [ 1.95838800e-03]]
# state apres predict
# [[ 5.99486327e+02]
#  [ 2.51306316e+02]
#  [ 5.98640698e-02]
#  [ 1.38073043e+01]
#  [ 1.36051768e+01]
#  [ 1.36332526e+01]
#  [-1.63178118e+00]
#  [ 2.24586067e-03]]
# obstacle devant camera
# vecteur d'etats avant update qd  thym cache:  [[ 5.99486327e+02]
#  [ 2.51306316e+02]
#  [ 5.98640698e-02]
#  [ 1.38073043e+01]
#  [ 1.36051768e+01]
#  [ 1.36332526e+01]
#  [-1.63178118e+00]
#  [ 2.24586067e-03]]
# vecteur d'etats apres update qd  thym cache:  [[ 5.99483429e+02]
#  [ 2.51306534e+02]
#  [ 5.97650454e-02]
#  [ 1.35877142e+01]
#  [ 1.36514201e+01]
#  [ 1.36002380e+01]
#  [-1.62925705e+00]
#  [ 1.11764600e-03]]
# angle from camera: None
# <class 'numpy.float64'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10784/3403668298.py in <module>
#      89         #print(angle_thym)
#      90         y = [60,60]
# ---> 91         ctrl.set_motors(y[0],y[1],node)
#      92
#      93     #    switch_next=astolfi(kalman_pos,path[path_iter],angle_kalman,node)
#
# ~\Desktop\Master Robotics\Cours Obligatoire\Mobile Rob\Projet\EPFL_MoRo_Project\control.py in set_motors(left, right, node)
#      38 #middle level functions
#      39 def set_motors(left,right,node):
# ---> 40     aw(node.set_variables(motors(left,right)))
#      41
#      42 def stopmotors(node):
#
# ~\anaconda3\lib\site-packages\tdmclient\clientasync.py in aw(co)
#     166             r = await co
#     167
# --> 168         ClientAsync.run_async_program(prog)
#     169         return r
#
# ~\anaconda3\lib\site-packages\tdmclient\clientasync.py in run_async_program(prog)
#     151         try:
#     152             while True:
# --> 153                 co.send(None)
#     154         except StopIteration:
#     155             pass
#
# ~\anaconda3\lib\site-packages\tdmclient\clientasync.py in prog()
#     164         async def prog():
#     165             nonlocal r
# --> 166             r = await co
#     167
#     168         ClientAsync.run_async_program(prog)
#
# ~\anaconda3\lib\site-packages\tdmclient\clientasyncnode.py in set_variables(self, var_dict)
#      93     @types.coroutine
#      94     def set_variables(self, var_dict):
# ---> 95         result = yield from self.thymio.send_msg_and_get_result(
#      96             lambda notify:
#      97                 self.send_set_variables(var_dict, request_id_notify=notify)
#
# ~\anaconda3\lib\site-packages\tdmclient\clientasync.py in send_msg_and_get_result(self, send_fun)
#     128         while not done:
#     129             yield
# --> 130             sleep(self.DEFAULT_SLEEP)
#     131             self.process_waiting_messages()
#     132         return result
#
# KeyboardInterrupt:

# %%
cap=cv2.VideoCapture(1,cv2.CAP_DSHOW)
for i in range (5):
    _, frame = cap.read()
    time.sleep(1)
    print("frame {}".format(i))

#cap.release()
#plt.figure()
#plt.imshow(frame)
#plt.show()

#time.sleep(1)
state=0
margin = 40
switch_next=0
path_iter=1
obst = [0,0,0]     # measurements from left, middle, right prox sensors
obstThrL = 2500      # low obstacle threshold to switch state 3->2
obstThrL2 = 3000
obstThrH = 4000      # high obstacle threshold to switch state 2->3 
y = [0,0]          # powers given to motor wheels

#init des variables Kalman, et visu de la trace
KF = ExtendedKalmanFilterAstolfi()
KF.set_time_stamp(time.time())

sensor_package = []
kalman_pos = []

coordThym = []
coordKalm = []

while (cap.isOpened()):
    _, frame = cap.read()
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    #final=vis.img_calibration(img, corner_coord)
    #img= cv2.flip(img, 0)
    if(state==0):
        corner_coord=vis.find_corners(img)
        final=vis.img_calibration(img, corner_coord)
        init=initialisation(final)
        path=glob.global_pathplanning(init[0],init[1],init[2],margin)
        
        init_pos = [init[0][0], init[0][1]]
        
        KF.init_state_vector(init_pos[0],init_pos[1],1.7,0,0,0,0,0)   #xxx a rendre plus joli
        angle_kalman = 1.7 
        state=2
    #if state==1:
     #   time.sleep(6)
      #  print("time sleep over")
       # _, frame1 = cap.read()
        #plt.figure()
        #plt.imshow(frame1)
        #plt.show()
        #img1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)
        #state=2
    if (state==2):
        final=vis.img_calibration(img, corner_coord)
        #plt.figure()
        #plt.imshow(final1)
        #plt.show()
        pos_thym=vis.detectThymio(final)[0]
        angle_thym=vis.directionThymio(final)
        
        vit_roue_droite = ctrl.read_motors_speed(node,client)[1]#xxx droite ou gauche a verifier
        vit_roue_gauche = ctrl.read_motors_speed(node,client)[0]#droite ou gauche a verifier
        sensor_package = [pos_thym[0], pos_thym[1], angle_thym, vit_roue_droite, vit_roue_gauche]
 #       print(sensor_package)
        if(bool(angle_thym)):
            if(abs(angle_thym-angle_kalman)>0.4):
                print("trop grande différence d'angle detectée")
                sensor_package = [None, None, None, vit_roue_droite, vit_roue_gauche]
            else:
                print("différence d'angle correcte")
        E = kalman_step_complet(sensor_package,KF)
        kalman_pos = [E[0], E[1]]
        kalman_pos = np.squeeze(np.asarray(kalman_pos))
 #       print("kalman pos: {}".format(kalman_pos))
        print(type(kalman_pos[0]))
        angle_kalman=E[2]
        angle_kalman = np.squeeze(np.asarray(angle_kalman[0]))
 #       print("kalman angle: {}".format(angle_kalman))
        
        #print(pos_thym)
        #print(angle_thym)
        #y = [50,50]
        #ctrl.set_motors(y[0],y[1],node)
        switch_next=astolfi(kalman_pos,path[path_iter],angle_kalman,node)
        if(switch_next==1):
            path_iter=path_iter+1
            print("path iter ",path_iter)
            if(path_iter==len(path)):
                ctrl.stopmotors(node)
                print("finish")
                state=4
                
        #local avoidance
        # get the proximity sensors values and obstacle update
        #prox_horizontal = ctrl.read_prox_sensors(node,client)
        #obst = [prox_horizontal[0], prox_horizontal[2], prox_horizontal[4]]
        # update the state and speed motors values
        #state = local.update_state(state,obstThrL,obstThrH, obst)  
    if(state==3):
   #     print("local_nav")
        prox_horizontal = ctrl.read_prox_sensors(node,client)
        obst = [prox_horizontal[0], prox_horizontal[2], prox_horizontal[4]]
        state = local.update_state(state,obstThrL,obstThrH, obst)
  #      print("obstacles values", obst)
        y = local.local_nav(prox_horizontal,y)
   #     print("y ",y)
        ctrl.set_motors(y[0],y[1],node)
    if state==4:
        break
    vis.printGlobalPath(path, final)
   # printThymio(pos_thym, coordThym)
 #   print(kalman_pos)
 #   print(coordKalm)
    printThymioKalm(kalman_pos,coordKalm)
    cv2.imshow("results", final)
    if cv2.waitKey(1) & 0xFF ==ord('q'):
        break
        
cap.release()
#cv2.destroyAllWindows()
# Out:
# frame 0
# frame 1
# frame 2
# frame 3
# frame 4
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 496.98it/s]
# Visibility graph points:  [[Point(387.30, 244.63), Point(389.71, 381.62), Point(533.70, 379.37), Point(531.29, 242.38)], [Point(128.76, 193.49), Point(125.24, 378.47), Point(282.24, 380.51), Point(285.76, 195.53)], [Point(347.08, -15.42), Point(235.92, 70.27), Point(329.93, 178.03), Point(441.08, 90.04)]]
#
# Shortest path distance: 603.0510151980382
#
# 0    POLYGON ((387.303 244.631, 389.706 381.619, 53...
# 1    POLYGON ((128.764 193.487, 125.241 378.474, 28...
# 2    POLYGON ((347.078 -15.419, 235.918 70.267, 329...
# 0                              POINT (103.630 344.568)
# 1                              POINT (128.764 193.487)
# 2                              POINT (329.927 178.033)
# 3                               POINT (542.522 50.064)
# dtype: geometry
#
# path  0    POINT (103.630 344.568)
# 1    POINT (128.764 193.487)
# 2    POINT (329.927 178.033)
# 3     POINT (542.522 50.064)
# dtype: geometry
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 0.0
# 0.0
# --------------------------------------------
# temps entre samples:  0.2529726028442383
# state avant predict
# [[103.63012695]
#  [344.56790161]
#  [  1.7       ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]]
# state apres predict
# [[103.63012695]
#  [344.56790161]
#  [  1.7       ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 0.0
# 0.0
# --------------------------------------------
# temps entre samples:  0.18102264404296875
# state avant predict
# [[ 38.17145477]
#  [338.1604456 ]
#  [  1.64095639]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]]
# state apres predict
# [[ 38.17145477]
#  [338.1604456 ]
#  [  1.64095639]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]
#  [  0.        ]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 0.114243794960844
# 0.11427188643288108
# --------------------------------------------
# temps entre samples:  0.15816736221313477
# state avant predict
# [[ 3.40487698e+01]
#  [ 3.36145374e+02]
#  [ 1.62336539e+00]
#  [ 1.14243795e-01]
#  [ 1.14271886e-01]
#  [-9.15401434e-03]
#  [-1.30259134e-01]
#  [-3.56717105e-07]]
# state apres predict
# [[ 3.40473220e+01]
#  [ 3.36124771e+02]
#  [ 1.62336533e+00]
#  [ 1.14243795e-01]
#  [ 1.14271886e-01]
#  [-1.91229654e-01]
#  [-1.04353865e-01]
#  [-3.12127467e-07]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 6.718544992847174
# 15.01013407083627
# --------------------------------------------
# temps entre samples:  0.13783025741577148
# state avant predict
# [[ 3.39031597e+01]
#  [ 3.35162554e+02]
#  [ 1.59424808e+00]
#  [ 6.71854499e+00]
#  [ 1.50101341e+01]
#  [-5.58751900e-01]
#  [-7.10398505e+00]
#  [-6.00519248e-02]]
# state apres predict
# [[ 3.38261468e+01]
#  [ 3.34183410e+02]
#  [ 1.58597111e+00]
#  [ 6.71854499e+00]
#  [ 1.50101341e+01]
#  [-1.75704541e+01]
#  [-1.04551943e+01]
#  [-9.21287675e-02]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 12.089294613811116
# 28.840308905755307
# --------------------------------------------
# temps entre samples:  0.14818882942199707
# state avant predict
# [[ 3.39829138e+01]
#  [ 3.32843040e+02]
#  [ 1.53686808e+00]
#  [ 1.20892946e+01]
#  [ 2.88403089e+01]
#  [-1.75844025e+01]
#  [-1.69060750e+01]
#  [-1.55168435e-01]]
# state apres predict
# [[ 3.13771018e+01]
#  [ 3.30337749e+02]
#  [ 1.51387385e+00]
#  [ 1.20892946e+01]
#  [ 2.88403089e+01]
#  [-3.07393982e+01]
#  [-2.15199205e+01]
#  [-1.86122381e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 17.337937150506306
# 37.98997240902085
# --------------------------------------------
# temps entre samples:  0.13450360298156738
# state avant predict
# [[ 3.42002791e+01]
#  [ 3.27687862e+02]
#  [ 1.39740397e+00]
#  [ 1.73379372e+01]
#  [ 3.79899724e+01]
#  [-2.63081248e+01]
#  [-2.63186551e+01]
#  [-2.15562352e-01]]
# state apres predict
# [[ 3.06617415e+01]
#  [ 3.24147908e+02]
#  [ 1.36841006e+00]
#  [ 1.73379372e+01]
#  [ 3.79899724e+01]
#  [-3.33053356e+01]
#  [-3.39185548e+01]
#  [-2.29467058e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 21.001314186398464
# 42.53261353985842
# --------------------------------------------
# temps entre samples:  0.13621211051940918
# state avant predict
# [[ 3.48681605e+01]
#  [ 3.21885955e+02]
#  [ 1.30910881e+00]
#  [ 2.10013142e+01]
#  [ 4.25326135e+01]
#  [-2.57848266e+01]
#  [-3.55045807e+01]
#  [-2.36137135e-01]]
# state apres predict
# [[ 3.13559548e+01]
#  [ 3.17049802e+02]
#  [ 1.27694407e+00]
#  [ 2.10013142e+01]
#  [ 4.25326135e+01]
#  [-3.19521307e+01]
#  [-4.14443122e+01]
#  [-2.39236659e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 24.873275559939614
# 45.519007907075334
# --------------------------------------------
# temps entre samples:  0.14837002754211426
# state avant predict
# [[ 3.59152687e+01]
#  [ 3.17954564e+02]
#  [ 1.23168768e+00]
#  [ 2.48732756e+01]
#  [ 4.55190079e+01]
#  [-2.37190605e+01]
#  [-4.16552784e+01]
#  [-2.32491839e-01]]
# state apres predict
# [[ 3.23960710e+01]
#  [ 3.11774169e+02]
#  [ 1.19719286e+00]
#  [ 2.48732756e+01]
#  [ 4.55190079e+01]
#  [-2.91740235e+01]
#  [-4.76122250e+01]
#  [-2.29397026e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# failure in identifying corners
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 26.48966439114603
# 47.16630797235052
# --------------------------------------------
# temps entre samples:  0.13660478591918945
# state avant predict
# [[ 3.76835046e+01]
#  [ 3.15311751e+02]
#  [ 1.18674094e+00]
#  [ 2.64896644e+01]
#  [ 4.71663080e+01]
#  [-1.98865289e+01]
#  [-4.54458112e+01]
#  [-2.29627220e-01]]
# state apres predict
# [[ 3.49669096e+01]
#  [ 3.09103635e+02]
#  [ 1.15537276e+00]
#  [ 2.64896644e+01]
#  [ 4.71663080e+01]
#  [-2.67226319e+01]
#  [-5.05208167e+01]
#  [-2.29740484e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 28.130345444126398
# 47.11581483608458
# --------------------------------------------
# temps entre samples:  0.13815522193908691
# state avant predict
# [[ 3.97777339e+01]
#  [ 3.10497101e+02]
#  [ 1.14927133e+00]
#  [ 2.81303454e+01]
#  [ 4.71158148e+01]
#  [-1.90284829e+01]
#  [-4.80059966e+01]
#  [-2.16837707e-01]]
# state apres predict
# [[ 3.71488496e+01]
#  [ 3.03864822e+02]
#  [ 1.11931407e+00]
#  [ 2.81303454e+01]
#  [ 4.71158148e+01]
#  [-2.40606604e+01]
#  [-5.20211775e+01]
#  [-2.10949660e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 29.418961839477767
# 46.31440485651209
# --------------------------------------------
# temps entre samples:  0.14912986755371094
# state avant predict
# [[ 3.94886512e+01]
#  [ 3.05437827e+02]
#  [ 1.16879006e+00]
#  [ 2.94189618e+01]
#  [ 4.63144049e+01]
#  [-2.04499237e+01]
#  [-5.05649219e+01]
#  [-1.95002451e-01]]
# state apres predict
# [[ 3.64389567e+01]
#  [ 2.97897087e+02]
#  [ 1.13970937e+00]
#  [ 2.94189618e+01]
#  [ 4.63144049e+01]
#  [-2.59139198e+01]
#  [-5.21645763e+01]
#  [-1.87727145e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 30.199491404709647
# 45.58725115808625
# --------------------------------------------
# temps entre samples:  0.13553786277770996
# state avant predict
# [[ 4.13514933e+01]
#  [ 3.02327877e+02]
#  [ 1.10555724e+00]
#  [ 3.01994914e+01]
#  [ 4.55872512e+01]
#  [-1.70845458e+01]
#  [-4.83582389e+01]
#  [-1.76219171e-01]]
# state apres predict
# [[ 3.90358904e+01]
#  [ 2.95773504e+02]
#  [ 1.08167288e+00]
#  [ 3.01994914e+01]
#  [ 4.55872512e+01]
#  [-2.04402857e+01]
#  [-5.26607078e+01]
#  [-1.70975108e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 30.198273749380732
# 45.12169826966714
# --------------------------------------------
# temps entre samples:  0.1381974220275879
# state avant predict
# [[ 4.28905097e+01]
#  [ 2.99290838e+02]
#  [ 1.08705620e+00]
#  [ 3.01982737e+01]
#  [ 4.51216983e+01]
#  [-1.36548832e+01]
#  [-4.90179706e+01]
#  [-1.67427613e-01]]
# state apres predict
# [[ 4.10034401e+01]
#  [ 2.92516681e+02]
#  [ 1.06391813e+00]
#  [ 3.01982737e+01]
#  [ 4.51216983e+01]
#  [-1.87258898e+01]
#  [-5.23791764e+01]
#  [-1.65815828e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 30.54670111028583
# 43.437525338561784
# --------------------------------------------
# temps entre samples:  0.14463567733764648
# state avant predict
# [[ 4.43172194e+01]
#  [ 2.96273638e+02]
#  [ 1.07971752e+00]
#  [ 3.05467011e+01]
#  [ 4.34375253e+01]
#  [-1.27321721e+01]
#  [-4.86504212e+01]
#  [-1.50302530e-01]]
# state apres predict
# [[ 4.24756930e+01]
#  [ 2.89237051e+02]
#  [ 1.05797841e+00]
#  [ 3.05467011e+01]
#  [ 4.34375253e+01]
#  [-1.77763392e+01]
#  [-5.14558482e+01]
#  [-1.43231380e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 29.681361010774857
# 42.10456610584536
# --------------------------------------------
# temps entre samples:  0.1378803253173828
# state avant predict
# [[ 4.57698583e+01]
#  [ 2.92447949e+02]
#  [ 1.04534186e+00]
#  [ 2.96813610e+01]
#  [ 4.21045661e+01]
#  [-1.23149987e+01]
#  [-4.76369482e+01]
#  [-1.39659747e-01]]
# state apres predict
# [[ 4.40718622e+01]
#  [ 2.85879751e+02]
#  [ 1.02608552e+00]
#  [ 2.96813610e+01]
#  [ 4.21045661e+01]
#  [-1.44546316e+01]
#  [-4.98713361e+01]
#  [-1.38035612e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 29.64084521611236
# 41.600154487484374
# --------------------------------------------
# temps entre samples:  0.14735031127929688
# state avant predict
# [[ 4.69802252e+01]
#  [ 2.87945769e+02]
#  [ 1.01787877e+00]
#  [ 2.96408452e+01]
#  [ 4.16001545e+01]
#  [-9.90088844e+00]
#  [-4.69999709e+01]
#  [-1.34492816e-01]]
# state apres predict
# [[ 4.55213262e+01]
#  [ 2.81020308e+02]
#  [ 9.98061213e-01]
#  [ 2.96408452e+01]
#  [ 4.16001545e+01]
#  [-1.21479583e+01]
#  [-4.93542561e+01]
#  [-1.32881214e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>
# elements:  2
# elements:  2
# différence d'angle correcte
# Vitesses droite / gauche -------------------
# 29.580055301195966
# 40.149306313677414
# --------------------------------------------
# temps entre samples:  0.1349506378173828
# state avant predict
# [[ 4.90336391e+01]
#  [ 2.85323708e+02]
#  [ 1.00865695e+00]
#  [ 2.95800553e+01]
#  [ 4.01493063e+01]
#  [-6.11067711e+00]
#  [-4.49475971e+01]
#  [-1.22269854e-01]]
# state apres predict
# [[ 4.82089994e+01]
#  [ 2.79258001e+02]
#  [ 9.92156558e-01]
#  [ 2.95800553e+01]
#  [ 4.01493063e+01]
#  [-1.11721772e+01]
#  [-4.82432517e+01]
#  [-1.17436122e-01]]
# dans test de distance
# bonne distance detectee, update
# pas d'obstacle devant camera
# <class 'numpy.float64'>

# %%
type(kalman_pos)
round(-10.939384)
print(kalman_pos)
print(round(kalman_pos[0]))
round(-294992929.8484)

# %%
print("kalman pos: ",kalman_pos)
print("kalman pos: ", np.asarray(kalman_pos[0][0]))
print("kalman pos: ", np.squeeze(np.asarray(kalman_pos))[0])

# %%
ctrl.stopmotors(node)

# %%
test=[[None,None],[None,None]]
if bool(not test[0][0]):
    print("zeub")

# %%
def detectThymio(imgRGB):
    pts=[]
    #p1 is the big circle and p2 the little
    p1=[]
    p2=[]
    lower=np.array([10,30,30])
    upper=np.array([40,255,255])
    nb_iterations=1
    img_hsv = cv2.cvtColor(imgRGB, cv2.COLOR_RGB2HSV)
    mask = cv2.inRange(img_hsv, lower, upper)
    img_hsv = cv2.blur(img_hsv,(7,7))
    mask = cv2.erode(mask, None, iterations = nb_iterations)
    mask = cv2.dilate(mask, None, iterations = nb_iterations)
    elements,_ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    print(len(elements))
    if len(elements) > 0:
        #sorting the detected contours by descending area size
        elements.sort(key=cv2.contourArea, reverse=True)
        #finding big circle
        c=elements[0]
        ((x,y),rayon) = cv2.minEnclosingCircle(c)
        #finding little circle
        c2=elements[1]
        ((x2,y2),rayon2) = cv2.minEnclosingCircle(c2)
        p1=[x,y]
        p2=[x2,y2]
        pts=[p1,p2]
    return pts

#print(detectThymio(final))
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
corner_coord=vis.find_corners(frame)
final=vis.img_calibration(frame, corner_coord)
print(detectThymio(final)[0])

# %%
print(init)

# %%
# Navigation initialisation
checkp=1           # goal checkpoint
actual_angle=0     # angle to xy axis
y = [0,0]          # powers given to motor wheels

# FSM initialisation
state = 0          # States FSM 0=global nav, 1=local nav
obst = [0,0,0]     # measurements from left, middle, right prox sensors
obstThrL = 2500      # low obstacle threshold to switch state 1->0
obstThrL2 = 3000
obstThrH = 4000      # high obstacle threshold to switch state 0->1  

while True:
    
    # get the proximity sensors values and obstacle update
    prox_horizontal = ctrl.read_prox_sensors(node,client)
    obst = [prox_horizontal[0], prox_horizontal[2], prox_horizontal[4]]
    
    # update the state and speed motors values
    state = local.update_state(state,obstThrL,obstThrH, obst)
    y = ctrl.read_motors_speed(node,client)
    
    print("state", state)

    if state == 0:
        
        """
        # With positon estimation when vision and/or kalman ready
        
        actual,angle = getting_vis()
        pred_pos,pred_angle = kalman(actual, angle)
        
        actual_pos=pred_pos
        actual_angle=pred_angle
        
        if actual_pos == checkpoints[checkp]: # other option: if (actual_pos - checkpoints[checkp]) < error
            checkp=checkp+1
        goal_pos=checkpoints[checkp]
        
        y = ctrl.astolfi2(actual_pos, goal_pos, actual_angle, node)
        
        """
        y = [50,50]
        ctrl.set_motors(y[0],y[1],node)

    elif state == 1:
        print("obstacles values", obst)
        y = local.local_nav(prox_horizontal,y)
        print("y ",y)
        ctrl.set_motors(y[0],y[1],node)

ctrl.stopmotors(node)

# %%
ctrl.stopmotors(node)
